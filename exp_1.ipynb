# %%
import pandas as pd
from pathlib import Path

data_dir = Path("calibro_original")
df_obs = pd.read_csv(data_dir / "obs.csv")
df_TT = pd.read_csv(data_dir / "calib_sampling-EMS-ABM-u.csv")
df_Y  = pd.read_csv(data_dir / "df_q1_q3_q4_hvac_filtered.csv")

# df_obs.head(), df_TT.head(), df_Y.head()
print("=== FILE DIMENSIONS ===")
print(f"obs shape: {df_obs.shape}")
print(f"TT shape:      {df_TT.shape}")
print(f"Y shape:       {df_Y.shape}")
print("\n=== COLUMN NAMES ===")
print("obs:", list(df_obs.columns))
print("TT:",  list(df_TT.columns))
print("Y:",   list(df_Y.columns))
# Out:
# === FILE DIMENSIONS ===
# obs shape: (120, 1)
# TT shape:      (20, 6)
# Y shape:       (120, 20)
#
# === COLUMN NAMES ===
# obs: ['actual']
# TT: ['BaseLoad_Q1', 'BaseLoad_Q34', 'PplInt_Q1', 'PplInt_Q34', 'EqInt_Q1', 'EqInt_Q34']
# Y: ['sample_0_full', 'sample_1_full', 'sample_2_full', 'sample_3_full', 'sample_4_full', 'sample_5_full', 'sample_6_full', 'sample_7_full', 'sample_8_full', 'sample_9_full', 'sample_10_full', 'sample_11_full', 'sample_12_full', 'sample_13_full', 'sample_14_full', 'sample_15_full', 'sample_16_full', 'sample_17_full', 'sample_18_full', 'sample_19_full']

# %% [markdown]
# # Coding

# %%
# ================================================================
#  USER CONFIGURATION FOR THE ENTIRE EXPERIMENT
# ================================================================

# ---- experiment folder name ----
EXP_NAME = "exp_1"

# ---- area normalisation ----
AREA_M2 = 9184

# ---- March extraction ----
START_DATE = "2023-03-01"
END_DATE   = "2023-04-01"

# ---- Source files ----
SRC_METERING = "../ihg_generator/Metering.csv"
SRC_TT       = "../eplus_diagnosis/output-AUTO2_csv/samples_AUTO2.csv"
SRC_Y        = "../eplus_diagnosis/output-AUTO2_csv/DistrictHeatingWater_Facility_timeseries.csv"

# ---- Column names ----
METERING_TIMESTAMP = "Timestamp"
METERING_COLUMN    = "Main Heating"   # column to extract for obs

TT_DROP_COLUMNS = ["CSV File"]        # columns to remove from TT

# ---- R calibration environment name ----
CALIBRO_NAME = "simplest"

# ---- Rscript binary (leave default if in PATH) ----
RSCRIPT_BIN = "Rscript"

print("✓ Configuration loaded.")
# Out:
# ✓ Configuration loaded.

# %%
import pandas as pd
from pathlib import Path
import subprocess
import sys

# ================================================================
# 0. Resolve experiment directories
# ================================================================
base_dir = Path(".").resolve()
exp_dir = base_dir / EXP_NAME

data_dir  = exp_dir / "data"
code_dir  = exp_dir / "code"
output_dir = exp_dir / "output"

for d in [data_dir, code_dir, output_dir]:
    d.mkdir(parents=True, exist_ok=True)

print(f"[INFO] Experiment folder prepared at: {exp_dir}")


# ================================================================
# 1. Extract obs.csv (March + normalised)
# ================================================================
df_meter = pd.read_csv(SRC_METERING)
df_meter[METERING_TIMESTAMP] = pd.to_datetime(df_meter[METERING_TIMESTAMP], dayfirst=True)

df_obs = df_meter.loc[
    (df_meter[METERING_TIMESTAMP] >= START_DATE) &
    (df_meter[METERING_TIMESTAMP] <  END_DATE),
    [METERING_COLUMN]
].reset_index(drop=True)

# area normalisation
df_obs[METERING_COLUMN] = df_obs[METERING_COLUMN] / AREA_M2

df_obs.to_csv(data_dir / "obs.csv", index=False)
print("[INFO] obs.csv saved:", df_obs.shape)


# ================================================================
# 2. Extract TT.csv
# ================================================================
df_TT = pd.read_csv(SRC_TT)

for col in TT_DROP_COLUMNS:
    if col in df_TT.columns:
        df_TT = df_TT.drop(columns=[col])

df_TT.to_csv(data_dir / "TT.csv", index=False)
print("[INFO] TT.csv saved:", df_TT.shape)


# ================================================================
# 3. Extract Y.csv (March)
# ================================================================
df_Y = pd.read_csv(SRC_Y)

# auto-detect timestamp column
ts_cols = [c for c in df_Y.columns if "time" in c.lower() or "stamp" in c.lower()]
if not ts_cols:
    raise ValueError("❌ No timestamp column found in Y file")
ts_col = ts_cols[0]

df_Y[ts_col] = pd.to_datetime(df_Y[ts_col])

df_Y_march = df_Y.loc[
    (df_Y[ts_col] >= START_DATE) &
    (df_Y[ts_col] <  END_DATE)
].reset_index(drop=True)

df_Y_final = df_Y_march.drop(columns=[ts_col])

df_Y_final.to_csv(data_dir / "Y.csv", index=False)
print("[INFO] Y.csv saved:", df_Y_final.shape)


# ================================================================
# 4. Validate Calibro shape requirements
# ================================================================
if df_obs.shape[0] != df_Y_final.shape[0]:
    raise ValueError("❌ obs and Y row count mismatch!")

print("✓ Shape validation passed.")


# ================================================================
# 5. Generate R script
# ================================================================
r_script_path = code_dir / "run_calibro.R"

r_code = f"""
setwd("{output_dir}")

library(calibro)

CE <- calEnv$new(name = '{CALIBRO_NAME}')

CE$add.ds(
    name = 'data1',
    Y.star = '{data_dir}/obs.csv',
    TT     = '{data_dir}/TT.csv',
    Y      = '{data_dir}/Y.csv'
)

CE$rd = 'pca'
CE$sa = 'sobolSmthSpl'
CE$ret = list(mthd = 'ng.screening')
CE$mdls = 'gpr.ng.sePar01_whitePar01'
CE$train = list(type = 'training', alg = 'amoeba')
CE$cals = 'cal.gpr.ng'
CE$cal.mcmc = list(alg = 'amg')

CE$cal.res()

# IMPORTANT: no 'path' argument allowed
CE$genReport(
    type = 'pdf',
    out  = c('dss','cal')
)
"""

with open(r_script_path, "w") as f:
    f.write(r_code)

print("[INFO] R script generated:", r_script_path)


# ================================================================
# 6. Run Rscript
# ================================================================
print("\n[INFO] Running Calibro Rscript...")
cmd = [RSCRIPT_BIN, str(r_script_path)]
result = subprocess.run(cmd)

if result.returncode == 0:
    print("✓ Calibro finished successfully.")
else:
    print("❌ Calibro failed.")


print(f"\n🎉 Experiment complete. Results saved to: {output_dir}")
# Out:
# [INFO] Experiment folder prepared at: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_1
# [INFO] obs.csv saved: (744, 1)
# [INFO] TT.csv saved: (100, 6)
# [INFO] Y.csv saved: (744, 100)
# ✓ Shape validation passed.
# [INFO] R script generated: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_1/code/run_calibro.R
#
# [INFO] Running Calibro Rscript...
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:46.334591
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00299 mins) ***
#
#  best y: 690.469443083692
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.002363
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.9997
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 1
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 130800000
#
# *** Simulation 2 / 5 (elapsed time: 0.00511 mins) ***
#
#  best y: 810.290192170576
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.7468
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.653
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3128
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 126500000
#
# *** Simulation 3 / 5 (elapsed time: 0.00704 mins) ***
#
#  best y: 810.290192170576
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.7468
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.653
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3128
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 126500000
#
# *** Simulation 4 / 5 (elapsed time: 0.00915 mins) ***
#
#  best y: 810.290192170576
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.7468
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.653
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3128
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 126500000
#
# *** Simulation 5 / 5 (elapsed time: 0.0119 mins) ***
#
#  best y: 810.290192170576
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.7468
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.653
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3128
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 126500000
#
# *** Simulation 6 / 5 (elapsed time: 0.0145 mins) ***
#
#  best y: 810.290192170576
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.7468
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.653
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3128
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 126500000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:47.27063
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00199 mins) ***
#
#  best y: 628.870366862597
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.6259
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.01159
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 1
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9998
# 	 %SIGMA1@wn2.pc1 = 98470000
#
# *** Simulation 2 / 5 (elapsed time: 0.00438 mins) ***
#
#  best y: 693.651025709073
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.6697
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.9997
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.3206
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 97030000
#
# *** Simulation 3 / 5 (elapsed time: 0.00764 mins) ***
#
#  best y: 693.651025709073
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.6697
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.9997
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.3206
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 97030000
#
# *** Simulation 4 / 5 (elapsed time: 0.00959 mins) ***
#
#  best y: 785.353186393246
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.7796
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.7004
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.2992
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 100400000
#
# *** Simulation 5 / 5 (elapsed time: 0.0128 mins) ***
#
#  best y: 791.840642280334
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.8031
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.72
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.5353
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 98620000
#
# *** Simulation 6 / 5 (elapsed time: 0.0151 mins) ***
#
#  best y: 791.840642280334
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.8031
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.72
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.5353
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 98620000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:48.238906
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00204 mins) ***
#
#  best y: 454.911133742387
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.5875
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.3869
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9991
# 	 %SIGMA1@wn2.pc2 = 1961000
#
# *** Simulation 2 / 5 (elapsed time: 0.00429 mins) ***
#
#  best y: 454.911133742387
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.5875
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.3869
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9991
# 	 %SIGMA1@wn2.pc2 = 1961000
#
# *** Simulation 3 / 5 (elapsed time: 0.00645 mins) ***
#
#  best y: 454.911133742387
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.5875
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.3869
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9991
# 	 %SIGMA1@wn2.pc2 = 1961000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:48.692258
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00443 mins) ***
#
#  best y: 443.42586391334
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc3 = 0.7818
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.3572
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 3.465e-07
# 	 %ALPHA1@sePar01.pc3 = 0.9986
# 	 %SIGMA1@wn1.pc3 = 0.9997
# 	 %SIGMA1@wn2.pc3 = 298600
#
# *** Simulation 2 / 5 (elapsed time: 0.00601 mins) ***
#
#  best y: 443.42586391334
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc3 = 0.7818
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.3572
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 3.465e-07
# 	 %ALPHA1@sePar01.pc3 = 0.9986
# 	 %SIGMA1@wn1.pc3 = 0.9997
# 	 %SIGMA1@wn2.pc3 = 298600
#
# *** Simulation 3 / 5 (elapsed time: 0.00921 mins) ***
#
#  best y: 503.396063358131
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc3 = 0.8318
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.4177
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.6891
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9998
# 	 %SIGMA1@wn2.pc3 = 296700
#
# *** Simulation 4 / 5 (elapsed time: 0.0124 mins) ***
#
#  best y: 504.653863463508
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc3 = 0.8365
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.5003
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.7104
# 	 %ALPHA1@sePar01.pc3 = 0.9993
# 	 %SIGMA1@wn1.pc3 = 0.9998
# 	 %SIGMA1@wn2.pc3 = 298700
#
# *** Simulation 5 / 5 (elapsed time: 0.0159 mins) ***
#
#  best y: 504.653863463508
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc3 = 0.8365
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.5003
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.7104
# 	 %ALPHA1@sePar01.pc3 = 0.9993
# 	 %SIGMA1@wn1.pc3 = 0.9998
# 	 %SIGMA1@wn2.pc3 = 298700
#
# *** Simulation 6 / 5 (elapsed time: 0.0198 mins) ***
#
#  best y: 504.755544313061
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc3 = 0.824
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.4877
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.6988
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9998
# 	 %SIGMA1@wn2.pc3 = 299300
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:49.93887
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00168 mins) ***
#
#  best y: 379.446265507377
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.0464
# 	 %ALPHA1@sePar01.pc5 = 0.9995
# 	 %SIGMA1@wn1.pc5 = 0.9974
# 	 %SIGMA1@wn2.pc5 = 26260
#
# *** Simulation 2 / 5 (elapsed time: 0.00257 mins) ***
#
#  best y: 379.446265507377
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.0464
# 	 %ALPHA1@sePar01.pc5 = 0.9995
# 	 %SIGMA1@wn1.pc5 = 0.9974
# 	 %SIGMA1@wn2.pc5 = 26260
#
# *** Simulation 3 / 5 (elapsed time: 0.00374 mins) ***
#
#  best y: 379.446265507377
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.0464
# 	 %ALPHA1@sePar01.pc5 = 0.9995
# 	 %SIGMA1@wn1.pc5 = 0.9974
# 	 %SIGMA1@wn2.pc5 = 26260
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:50.218823
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00122 mins) ***
#
#  best y: 361.620481349159
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 4.563e-09
# 	 %ALPHA1@sePar01.pc6 = 0.9994
# 	 %SIGMA1@wn1.pc6 = 0.9969
# 	 %SIGMA1@wn2.pc6 = 14230
#
# *** Simulation 2 / 5 (elapsed time: 0.00202 mins) ***
#
#  best y: 364.583621238387
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.2032
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9969
# 	 %SIGMA1@wn2.pc6 = 14340
#
# *** Simulation 3 / 5 (elapsed time: 0.00287 mins) ***
#
#  best y: 365.794596217329
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.01703
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.997
# 	 %SIGMA1@wn2.pc6 = 14290
#
# *** Simulation 4 / 5 (elapsed time: 0.00364 mins) ***
#
#  best y: 365.794596217329
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.01703
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.997
# 	 %SIGMA1@wn2.pc6 = 14290
#
# *** Simulation 5 / 5 (elapsed time: 0.00503 mins) ***
#
#  best y: 365.812813031843
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.01231
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.997
# 	 %SIGMA1@wn2.pc6 = 14300
#
# *** Simulation 6 / 5 (elapsed time: 0.00584 mins) ***
#
#  best y: 365.812813031843
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.01231
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.997
# 	 %SIGMA1@wn2.pc6 = 14300
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:50.622249
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00129 mins) ***
#
#  best y: 342.820328889667
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 1.921e-05
# 	 %ALPHA1@sePar01.pc7 = 0.9996
# 	 %SIGMA1@wn1.pc7 = 0.996
# 	 %SIGMA1@wn2.pc7 = 10790
#
# *** Simulation 2 / 5 (elapsed time: 0.00254 mins) ***
#
#  best y: 344.1420994171
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.04985
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9959
# 	 %SIGMA1@wn2.pc7 = 10820
#
# *** Simulation 3 / 5 (elapsed time: 0.00383 mins) ***
#
#  best y: 344.1420994171
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.04985
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9959
# 	 %SIGMA1@wn2.pc7 = 10820
#
# *** Simulation 4 / 5 (elapsed time: 0.00498 mins) ***
#
#  best y: 344.1420994171
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.04985
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9959
# 	 %SIGMA1@wn2.pc7 = 10820
#
# *** Simulation 5 / 5 (elapsed time: 0.00633 mins) ***
#
#  best y: 344.1420994171
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.04985
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9959
# 	 %SIGMA1@wn2.pc7 = 10820
#
# *** Simulation 6 / 5 (elapsed time: 0.00745 mins) ***
#
#  best y: 344.1420994171
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.04985
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9959
# 	 %SIGMA1@wn2.pc7 = 10820
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:51.123143
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00163 mins) ***
#
#  best y: 336.635213934548
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc8 = 5.551e-17
# 	 %ALPHA1@sePar01.pc8 = 0.9997
# 	 %SIGMA1@wn1.pc8 = 0.9956
# 	 %SIGMA1@wn2.pc8 = 8219
#
# *** Simulation 2 / 5 (elapsed time: 0.0026 mins) ***
#
#  best y: 338.380070027343
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc8 = 0.0007176
# 	 %ALPHA1@sePar01.pc8 = 0.9998
# 	 %SIGMA1@wn1.pc8 = 0.9955
# 	 %SIGMA1@wn2.pc8 = 8190
#
# *** Simulation 3 / 5 (elapsed time: 0.00352 mins) ***
#
#  best y: 338.380070027343
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc8 = 0.0007176
# 	 %ALPHA1@sePar01.pc8 = 0.9998
# 	 %SIGMA1@wn1.pc8 = 0.9955
# 	 %SIGMA1@wn2.pc8 = 8190
#
# *** Simulation 4 / 5 (elapsed time: 0.00431 mins) ***
#
#  best y: 338.380070027343
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc8 = 0.0007176
# 	 %ALPHA1@sePar01.pc8 = 0.9998
# 	 %SIGMA1@wn1.pc8 = 0.9955
# 	 %SIGMA1@wn2.pc8 = 8190
#
# *** Simulation 5 / 5 (elapsed time: 0.00493 mins) ***
#
#  best y: 338.380070027343
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc8 = 0.0007176
# 	 %ALPHA1@sePar01.pc8 = 0.9998
# 	 %SIGMA1@wn1.pc8 = 0.9955
# 	 %SIGMA1@wn2.pc8 = 8190
#
# *** Simulation 6 / 5 (elapsed time: 0.00638 mins) ***
#
#  best y: 338.380070027343
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc8 = 0.0007176
# 	 %ALPHA1@sePar01.pc8 = 0.9998
# 	 %SIGMA1@wn1.pc8 = 0.9955
# 	 %SIGMA1@wn2.pc8 = 8190
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 00:50:51.56055
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00157 mins) ***
#
#  best y: 342.662746948047
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc9 = 0.05366
# 	 %ALPHA1@sePar01.pc9 = 0.9997
# 	 %SIGMA1@wn1.pc9 = 0.9959
# 	 %SIGMA1@wn2.pc9 = 7705
#
# *** Simulation 2 / 5 (elapsed time: 0.00329 mins) ***
#
#  best y: 342.662746948047
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc9 = 0.05366
# 	 %ALPHA1@sePar01.pc9 = 0.9997
# 	 %SIGMA1@wn1.pc9 = 0.9959
# 	 %SIGMA1@wn2.pc9 = 7705
#
# *** Simulation 3 / 5 (elapsed time: 0.00431 mins) ***
#
#  best y: 342.662746948047
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc9 = 0.05366
# 	 %ALPHA1@sePar01.pc9 = 0.9997
# 	 %SIGMA1@wn1.pc9 = 0.9959
# 	 %SIGMA1@wn2.pc9 = 7705
#
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2025-11-13 00:50:53.433887
#  Number of chains: 1
#  Number of simulations: <until converged>
#
# *** Simulation 5 / <until converged> (elapsed time: 0.0769 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# b10_airloophvac             7
# b10_airloophvac             0.0084089 0.1672  827.6
# d2_htgsp_office_st          0.0024267 0.6386 3161.2
# e1_natural_ventilation_rate 0.0037025 0.1745  863.6
# %SIGMA@wn2*.pc.mu%          0.0005675 0.6804 3368.1
# %SIGMA@wn2*.pc1%            0.0005628 0.7009 3469.4
# %SIGMA@wn2*.pc2%            0.0005402 0.7196 3562.2
# %SIGMA@wn2*.pc3%            0.0005578 0.6758 3345.2
# %SIGMA@wn2*.pc5%            0.0005572 0.6799 3365.5
# a5_infiltration_rate        0.0207605 0.3770 1866.1
# %SIGMA@wn2*.pc6%            0.0005238 0.7361 3643.6
# %SIGMA@wn2*.pc7%            0.0005541 0.6955 3442.6
# %SIGMA@wn2*.pc8%            0.0005167 0.7580 3752.3
# %SIGMA@wn2*.pc9%            0.0005884 0.6372 3153.9
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# b10_airloophvac             3.605e-01 6.372e-01 7.987e-01 9.257e-01 9.933e-01
# d2_htgsp_office_st          4.149e-01 5.121e-01 5.606e-01 6.096e-01 7.138e-01
# e1_natural_ventilation_rate 6.632e-01 8.078e-01 8.917e-01 9.536e-01 9.956e-01
# %SIGMA@wn2*.pc.mu%          1.401e+05 1.463e+05 1.496e+05 1.529e+05 1.594e+05
# ...
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# b10_airloophvac             7.473e-01 1.907e-01 1.371e-03      3.395e-03
# d2_htgsp_office_st          5.612e-01 7.560e-02 5.435e-04      6.934e-04
# e1_natural_ventilation_rate 8.662e-01 9.816e-02 7.056e-04      1.740e-03
# %SIGMA@wn2*.pc.mu%          1.497e+05 4.920e+03 3.537e+01      4.234e+01
# %SIGMA@wn2*.pc1%            1.135e+05 3.716e+03 2.671e+01      3.190e+01
# %SIGMA@wn2*.pc2%            2.265e+03 7.240e+01 5.205e-01      6.239e-01
# %SIGMA@wn2*.pc3%            3.234e+02 1.063e+01 7.642e-02      9.223e-02
# %SIGMA@wn2*.pc5%            3.017e+01 9.765e-01 7.020e-03      8.244e-03
# a5_infiltration_rate        1.571e-01 1.403e-01 1.009e-03      1.617e-03
# %SIGMA@wn2*.pc6%            1.618e+01 5.211e-01 3.746e-03      4.417e-03
# %SIGMA@wn2*.pc7%            1.239e+01 3.997e-01 2.873e-03      3.378e-03
# %SIGMA@wn2*.pc8%            9.414e+00 3.053e-01 2.195e-03      2.588e-03
# %SIGMA@wn2*.pc9%            8.855e+00 2.882e-01 2.072e-03      2.454e-03
#                                     t    eff     s
# b10_airloophvac             0.0045433 0.1630  3154
# d2_htgsp_office_st          0.0012357 0.6143 11887
# e1_natural_ventilation_rate 0.0020081 0.1645  3184
# %SIGMA@wn2*.pc.mu%          0.0002829 0.6979 13504
# %SIGMA@wn2*.pc1%            0.0002809 0.7013 13570
# %SIGMA@wn2*.pc2%            0.0002755 0.6959 13466
# %SIGMA@wn2*.pc3%            0.0002852 0.6866 13285
# %SIGMA@wn2*.pc5%            0.0002732 0.7250 14029
# a5_infiltration_rate        0.0102943 0.3891  7530
# %SIGMA@wn2*.pc6%            0.0002729 0.7190 13913
# %SIGMA@wn2*.pc7%            0.0002727 0.7237 14004
# %SIGMA@wn2*.pc8%            0.0002749 0.7193 13919
# %SIGMA@wn2*.pc9%            0.0002771 0.7128 13793
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# b10_airloophvac             3
# %SIGMA@wn2*.pc5%            0.0002690 0.7285 14425
# a5_infiltration_rate        0.0101846 0.3894  7709
# %SIGMA@wn2*.pc6%            0.0002688 0.7231 14318
# %SIGMA@wn2*.pc7%            0.0002795 0.6743 13351
# %SIGMA@wn2*.pc8%            0.0002711 0.7215 14285
# %SIGMA@wn2*.pc9%            0.0002738 0.7134 14126
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# b10_airloophvac             3.310e-01 6.145e-01 7.745e-01 9.145e-01 9.937e-01
# d2_htgsp_office_st          4.140e-01 5.126e-01 5.604e-01 6.091e-01 7.119e-01
# e1_natural_ventilation_rate 6.523e-01 7.968e-01 8.831e-01 9.496e-01 9.958e-01
# %SIGMA@wn2*.pc.mu%          1.402e+05 1.464e+05 1.496e+05 1.530e+05 1.594e+05
# %SIGMA@wn2*.pc1%            1.065e+05 1.110e+05 1.135e+05 1.161e+05 1.210e+05
# %SIGMA@wn2*.pc2%            2.126e+03 2.214e+03 2.264e+03 2.314e+03 2.409e+03
# %SIGMA@wn2*.pc3%            3.029e+02 3.161e+02 3.233e+02 3.306e+02 3.445e+02
# %SIGMA@wn2*.pc5%            2.830e+01 2.952e+01 3.017e+01 3.084e+01 3.209e+01
# a5_infiltration_rate        7.099e-03 6.081e-02 1.202e-01 2.052e-01 5.473e-01
# %SIGMA@wn2*.pc6%            1.519e+01 1.583e+01 1.618e+01 1.654e+01 1.723e+01
# %SIGMA@wn2*.pc7%            1.161e+01 1.212e+01 1.238e+01 1.265e+01 1.318e+01
# %SIGMA@wn2*.pc8%            8.823e+00 9.204e+00 9.413e+00 9.619e+00 1.002e+01
# %SIGMA@wn2*.pc9%            8.308e+00 8.658e+00 8.851e+00 9.048e+00 9.431e+00
#
# *** Simulation 225 / <until converged> (elapsed time: 2.49 mins) ***
#
# Iterations = 2250:83246
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 20250
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# b10_airloophvac             7.479e-01 1.902e-01 1.336e-03       0.003293
# d2_htgsp_office_st          5.612e-01 7.552e-02 5.307e-04       0.000673
# e1_natural_ventilation_rate 8.666e-01 9.775e-02 6.869e-04       0.001685
# %SIGMA@wn2*.pc.mu%          1.497e+05 4.916e+03 3.455e+01      41.391950
# %SIGMA@wn2*.pc1%            1.135e+05 3.709e+03 2.606e+01      31.089070
# %SIGMA@wn2*.pc2%            2.264e+03 7.239e+01 5.087e-01       0.608314
# %SIGMA@wn2*.pc3%            3.234e+02 1.063e+01 7.472e-02       0.090280
# %SIGMA@wn2*.pc5%            3.017e+01 9.736e-01 6.842e-03       0.008004
# a5_infiltration_rate        1.572e-01 1.404e-01 9.863e-04       0.001578
# %SIGMA@wn2*.pc6%            1.618e+01 5.203e-01 3.656e-03       0.004301
# %SIGMA@wn2*.pc7%            1.239e+01 3.999e-01 2.810e-03       0.003314
# %SIGMA@wn2*.pc8%            9.414e+00 3.049e-01 2.143e-03       0.002524
# %SIGMA@wn2*.pc9%            8.855e+00 2.877e-01 2.022e-03       0.002393
#                                     t    eff     s
# b10_airloophvac             0.0044031 0.1647  3335
# d2_htgsp_office_st          0.0011993 0.6219 12593
# e1_natural_ventilation_rate 0.0019445 0.1662  3365
# %SIGMA@wn2*.pc.mu%          0.0002766 0.6966 14105
# %SIGMA@wn2*.pc1%            0.0002738 0.7028 14231
# %SIGMA@wn2*.pc2%            0.0002687 0.6993 14162
# %SIGMA@wn2*.pc3%            0.0002792 0.6851 13873
# %SIGMA@wn2*.pc5%            0.0002653 0.7307 14796
# a5_infiltration_rate        0.0100340 0.3909  7916
# %SIGMA@wn2*.pc6%            0.0002658 0.7227 14635
# %SIGMA@wn2*.pc7%            0.0002676 0.7187 14555
# %SIGMA@wn2*.pc8%            0.0002681 0.7210 14600
# %SIGMA@wn2*.pc9%            0.0002702 0.7142 14463
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# b10_airloophvac             3.324e-01 6.157e-01 7.749e-01 9.142e-01 9.937e-01
# d2_htgsp_office_st          4.143e-01 5.126e-01 5.604e-01 6.092e-01 7.117e-01
# e1_natural_ventilation_rate 6.535e-01 7.977e-01 8.835e-01 9.496e-01 9.958e-01
# %SIGMA@wn2*.pc.mu%          1.402e+05 1.463e+05 1.496e+05 1.529e+05 1.594e+05
# %SIGMA@wn2*.pc1%            1.065e+05 1.110e+05 1.135e+05 1.161e+05 1.210e+05
# %SIGMA@wn2*.pc2%            2.126e+03 2.214e+03 2.264e+03 2.313e+03 2.409e+03
# %SIGMA@wn2*.pc3%            3.029e+02 3.160e+02 3.233e+02 3.306e+02 3.445e+02
# %SIGMA@wn2*.pc5%            2.831e+01 2.952e+01 3.017e+01 3.084e+01 3.209e+01
# a5_infiltration_rate        7.005e-03 6.093e-02 1.202e-01 2.056e-01 5.477e-01
# %SIGMA@wn2*.pc6%            1.519e+01 1.583e+01 1.618e+01 1.653e+01 1.723e+01
# %SIGMA@wn2*.pc7%            1.161e+01 1.212e+01 1.238e+01 1.265e+01 1.318e+01
# %SIGMA@wn2*.pc8%            8.823e+00 9.204e+00 9.413e+00 9.620e+00 1.002e+01
# %SIGMA@wn2*.pc9%            8.308e+00 8.658e+00 8.851e+00 9.046e+00 9.430e+00
#
# *** Simulation 230 / <until converged> (elapsed time: 2.54 mins) ***
#
# Iterations = 2300:85096
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 20700
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# b10_airloophvac             7.490e-01 1.899e-01 1.320e-03      3.255e-03
# d2_htgsp_office_st          5.611e-01 7.555e-02 5.251e-04      6.652e-04
# e1_natural_ventilation_rate 8.671e-01 9.771e-02 6.791e-04      1.663e-03
# %SIGMA@wn2*.pc.mu%          1.497e+05 4.922e+03 3.421e+01      4.187e+01
# %SIGMA@wn2*.pc1%            1.135e+05 3.709e+03 2.578e+01      3.073e+01
# %SIGMA@wn2*.pc2%            2.264e+03 7.230e+01 5.025e-01      6.005e-01
# %SIGMA@wn2*.pc3%            3.234e+02 1.064e+01 7.394e-02      8.933e-02
# %SIGMA@wn2*.pc5%            3.017e+01 9.750e-01 6.777e-03      7.920e-03
# a5_infiltration_rate        1.569e-01 1.399e-01 9.724e-04      1.545e-03
# %SIGMA@wn2*.pc6%            1.618e+01 5.201e-01 3.615e-03      4.252e-03
# %SIGMA@wn2*.pc7%            1.239e+01 3.999e-01 2.780e-03      3.277e-03
# %SIGMA@wn2*.pc8%            9.414e+00 3.049e-01 2.119e-03      2.496e-03
# %SIGMA@wn2*.pc9%            8.854e+00 2.879e-01 2.001e-03      2.370e-03
#                                     t    eff     s
# b10_airloophvac             0.0043455 0.1645  3406
# d2_htgsp_office_st          0.0011855 0.6232 12900
# e1_natural_ventilation_rate 0.0019183 0.1667  3450
# %SIGMA@wn2*.pc.mu%          0.0002797 0.6678 13824
# %SIGMA@wn2*.pc1%            0.0002707 0.7037 14566
# %SIGMA@wn2*.pc2%            0.0002652 0.7003 14496
# %SIGMA@wn2*.pc3%            0.0002762 0.6850 14180
# %SIGMA@wn2*.pc5%            0.0002625 0.7321 15154
# a5_infiltration_rate        0.0098515 0.3959  8195
# %SIGMA@wn2*.pc6%            0.0002627 0.7229 14965
# %SIGMA@wn2*.pc7%            0.0002645 0.7197 14898
# %SIGMA@wn2*.pc8%            0.0002651 0.7212 14928
# %SIGMA@wn2*.pc9%            0.0002676 0.7133 14765
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# b10_airloophvac             3.336e-01 6.172e-01 7.762e-01 9.150e-01 9.937e-01
# d2_htgsp_office_st          4.143e-01 5.126e-01 5.604e-01 6.091e-01 7.118e-01
# e1_natural_ventilation_rate 6.542e-01 7.982e-01 8.842e-01 9.502e-01 9.958e-01
# %SIGMA@wn2*.pc.mu%          1.402e+05 1.464e+05 1.496e+05 1.530e+05 1.595e+05
# %SIGMA@wn2*.pc1%            1.064e+05 1.110e+05 1.135e+05 1.160e+05 1.210e+05
# %SIGMA@wn2*.pc2%            2.126e+03 2.214e+03 2.264e+03 2.313e+03 2.409e+03
# %SIGMA@wn2*.pc3%            3.029e+02 3.161e+02 3.233e+02 3.306e+02 3.445e+02
# %SIGMA@wn2*.pc5%            2.830e+01 2.952e+01 3.016e+01 3.084e+01 3.210e+01
# a5_infiltration_rate        7.019e-03 6.068e-02 1.200e-01 2.052e-01 5.466e-01
# %SIGMA@wn2*.pc6%            1.519e+01 1.583e+01 1.618e+01 1.653e+01 1.722e+01
# %SIGMA@wn2*.pc7%            1.162e+01 1.212e+01 1.238e+01 1.265e+01 1.318e+01
# %SIGMA@wn2*.pc8%            8.823e+00 9.204e+00 9.413e+00 9.619e+00 1.002e+01
# %SIGMA@wn2*.pc9%            8.308e+00 8.658e+00 8.851e+00 9.047e+00 9.430e+00
#
# $CALIBRATION_RESULTS
#                     PARAMETER     ESTIMATE        LOWER        UPPER
# 1             b10_airloophvac 9.979171e-01  0.834689582 9.982858e-01
# 2          d2_htgsp_office_st 1.532768e+01 14.504863103 1.626616e+01
# 3 e1_natural_ventilation_rate 8.842868e-01  0.616860507 8.930518e-01
# 4        a5_infiltration_rate 1.675536e-04  0.000161005 2.093933e-04
#
# $CALIBRATED_MODEL_GOF
#               sim        cals
# data1 0.006467767 0.006545167
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
#
#
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# ✓ Calibro finished successfully.
#
# 🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_1/output
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
