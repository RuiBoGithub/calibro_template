# %%
import pandas as pd
from pathlib import Path

data_dir = Path("calibro_original")
df_obs = pd.read_csv(data_dir / "obs.csv")
df_TT = pd.read_csv(data_dir / "calib_sampling-EMS-ABM-u.csv")
df_Y  = pd.read_csv(data_dir / "df_q1_q3_q4_hvac_filtered.csv")

# df_obs.head(), df_TT.head(), df_Y.head()
print("=== FILE DIMENSIONS ===")
print(f"obs shape: {df_obs.shape}")
print(f"TT shape:      {df_TT.shape}")
print(f"Y shape:       {df_Y.shape}")
print("\n=== COLUMN NAMES ===")
print("obs:", list(df_obs.columns))
print("TT:",  list(df_TT.columns))
print("Y:",   list(df_Y.columns))
# Out:
# === FILE DIMENSIONS ===
# obs shape: (120, 1)
# TT shape:      (20, 6)
# Y shape:       (120, 20)
#
# === COLUMN NAMES ===
# obs: ['actual']
# TT: ['BaseLoad_Q1', 'BaseLoad_Q34', 'PplInt_Q1', 'PplInt_Q34', 'EqInt_Q1', 'EqInt_Q34']
# Y: ['sample_0_full', 'sample_1_full', 'sample_2_full', 'sample_3_full', 'sample_4_full', 'sample_5_full', 'sample_6_full', 'sample_7_full', 'sample_8_full', 'sample_9_full', 'sample_10_full', 'sample_11_full', 'sample_12_full', 'sample_13_full', 'sample_14_full', 'sample_15_full', 'sample_16_full', 'sample_17_full', 'sample_18_full', 'sample_19_full']

# %% [markdown]
# # Coding

# %%
# Your revised Python pipeline with TT parameter scaling applied correctly

# ---- Unique dir ----
EXP_NAME = "exp_2"

# ---- Column names ----
METERING_COLUMN    = "Main Heating"
START_DATE = "2023-03-01"
END_DATE   = "2023-04-01"
AREA_M2 = 9184

# ---- Source files ----
SRC_METERING = "../ihg_generator/Metering.csv"
SRC_TT       = "../eplus_diagnosis/output-AUTO3_csv/samples_AUTO3.csv"
SRC_Y        = "../eplus_diagnosis/output-AUTO3_csv/DistrictHeatingWater_Facility_timeseries.csv"

# ---- R environment ----
CALIBRO_NAME = "simplest"
RSCRIPT_BIN = "Rscript"
PARAM_TO_SCALE = "a5_infiltration_rate"
SCALE_FACTOR = 1000

# ---- Fixed term ----
METERING_TIMESTAMP = "Timestamp"
TT_DROP_COLUMNS = ["CSV File"]

# %%
import pandas as pd
from pathlib import Path
import subprocess
import sys

# ================================================================
# 0. Resolve experiment directories
# ================================================================
base_dir = Path(".").resolve()
exp_dir = base_dir / EXP_NAME

data_dir  = exp_dir / "data"
code_dir  = exp_dir / "code"
output_dir = exp_dir / "output"

for d in [data_dir, code_dir, output_dir]:
    d.mkdir(parents=True, exist_ok=True)

print(f"[INFO] Experiment folder prepared at: {exp_dir}")


# ================================================================
# 1. Extract obs.csv (March + normalised)
# ================================================================
df_meter = pd.read_csv(SRC_METERING)
df_meter[METERING_TIMESTAMP] = pd.to_datetime(df_meter[METERING_TIMESTAMP], dayfirst=True)

df_obs = df_meter.loc[
    (df_meter[METERING_TIMESTAMP] >= START_DATE) &
    (df_meter[METERING_TIMESTAMP] <  END_DATE),
    [METERING_COLUMN]
].reset_index(drop=True)

# area normalisation
df_obs[METERING_COLUMN] = df_obs[METERING_COLUMN] / AREA_M2

df_obs.to_csv(data_dir / "obs.csv", index=False)
print("[INFO] obs.csv saved:", df_obs.shape)


# ================================================================
# 2. Extract TT.csv + rescale chosen parameter
# ================================================================
df_TT = pd.read_csv(SRC_TT)

# Drop unused columns
for col in TT_DROP_COLUMNS:
    if col in df_TT.columns:
        df_TT = df_TT.drop(columns=[col])

# ---- RESCALE ONE PARAMETER ----
if PARAM_TO_SCALE in df_TT.columns:
    df_TT[PARAM_TO_SCALE] = df_TT[PARAM_TO_SCALE] * SCALE_FACTOR
    print(f"[INFO] Scaled parameter '{PARAM_TO_SCALE}' by ×{SCALE_FACTOR}")
else:
    print(f"[WARNING] Parameter '{PARAM_TO_SCALE}' not found in TT columns. Available columns: {list(df_TT.columns)}")

# Save TT
df_TT.to_csv(data_dir / "TT.csv", index=False)
print("[INFO] TT.csv saved:", df_TT.shape)
# Out:
# [INFO] Experiment folder prepared at: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_2
# [INFO] obs.csv saved: (744, 1)
# [INFO] Scaled parameter 'a5_infiltration_rate' by ×1000
# [INFO] TT.csv saved: (100, 6)

# %%
# ================================================================
# 3. Extract Y.csv (March)
# ================================================================
df_Y = pd.read_csv(SRC_Y)

# auto-detect timestamp column
ts_cols = [c for c in df_Y.columns if "time" in c.lower() or "stamp" in c.lower()]
if not ts_cols:
    raise ValueError("❌ No timestamp column found in Y file")
ts_col = ts_cols[0]

df_Y[ts_col] = pd.to_datetime(df_Y[ts_col])

df_Y_march = df_Y.loc[
    (df_Y[ts_col] >= START_DATE) &
    (df_Y[ts_col] <  END_DATE)
].reset_index(drop=True)

df_Y_final = df_Y_march.drop(columns=[ts_col])

df_Y_final.to_csv(data_dir / "Y.csv", index=False)
print("[INFO] Y.csv saved:", df_Y_final.shape)


# ================================================================
# 4. Validate Calibro shape requirements
# ================================================================
if df_obs.shape[0] != df_Y_final.shape[0]:
    raise ValueError("❌ obs and Y row count mismatch!")

print("✓ Shape validation passed.")


# ================================================================
# 5. Generate R script
# ================================================================
r_script_path = code_dir / "run_calibro.R"

r_code = f"""
setwd("{output_dir}")

library(calibro)

CE <- calEnv$new(name = '{CALIBRO_NAME}')

CE$add.ds(
    name = 'data1',
    Y.star = '{data_dir}/obs.csv',
    TT     = '{data_dir}/TT.csv',
    Y      = '{data_dir}/Y.csv'
)

CE$rd = 'pca'
CE$sa = 'sobolSmthSpl'
CE$ret = list(mthd = 'ng.screening')
CE$mdls = 'gpr.ng.sePar01_whitePar01'
CE$train = list(type = 'training', alg = 'amoeba')
CE$cals = 'cal.gpr.ng'
CE$cal.mcmc = list(alg = 'amg')

CE$cal.res()

# IMPORTANT: no 'path' argument allowed
CE$genReport(
    type = 'pdf',
    out  = c('dss','cal')
)
"""

with open(r_script_path, "w") as f:
    f.write(r_code)

print("[INFO] R script generated:", r_script_path)


# ================================================================
# 6. Run Rscript
# ================================================================
print("\n[INFO] Running Calibro Rscript...")
cmd = [RSCRIPT_BIN, str(r_script_path)]
result = subprocess.run(cmd)

if result.returncode == 0:
    print("✓ Calibro finished successfully.")
else:
    print("❌ Calibro failed.")


print(f"\n🎉 Experiment complete. Results saved to: {output_dir}")
# Out:
# [INFO] Y.csv saved: (744, 100)
# ✓ Shape validation passed.
# [INFO] R script generated: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_2/code/run_calibro.R
#
# [INFO] Running Calibro Rscript...
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 21:18:06.661772
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00382 mins) ***
#
#  best y: 774.582700882554
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.3695
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 4.194e-09
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 106100000
#
# *** Simulation 2 / 5 (elapsed time: 0.00503 mins) ***
#
#  best y: 774.582700882554
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.3695
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 4.194e-09
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 106100000
#
# *** Simulation 3 / 5 (elapsed time: 0.00623 mins) ***
#
#  best y: 779.05691154886
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.8693
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.7887
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 106600000
#
# *** Simulation 4 / 5 (elapsed time: 0.00745 mins) ***
#
#  best y: 779.05691154886
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.8693
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.7887
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 106600000
#
# *** Simulation 5 / 5 (elapsed time: 0.0092 mins) ***
#
#  best y: 779.05691154886
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.8693
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.7887
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 106600000
#
# *** Simulation 6 / 5 (elapsed time: 0.0104 mins) ***
#
#  best y: 794.958087109205
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.4434
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3766
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 105900000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 21:18:07.34432
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00172 mins) ***
#
#  best y: 635.530506360859
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.5182
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.02822
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.9999
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9998
# 	 %SIGMA1@wn2.pc1 = 80580000
#
# *** Simulation 2 / 5 (elapsed time: 0.0042 mins) ***
#
#  best y: 699.086818296855
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.5767
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 1
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.3014
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 80060000
#
# *** Simulation 3 / 5 (elapsed time: 0.00631 mins) ***
#
#  best y: 708.222014167298
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 1
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.000817
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.2183
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 80460000
#
# *** Simulation 4 / 5 (elapsed time: 0.00908 mins) ***
#
#  best y: 708.222014167298
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 1
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.000817
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.2183
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 80460000
#
# *** Simulation 5 / 5 (elapsed time: 0.0107 mins) ***
#
#  best y: 708.222014167298
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 1
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.000817
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.2183
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 80460000
#
# *** Simulation 6 / 5 (elapsed time: 0.0145 mins) ***
#
#  best y: 785.6043010124
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.7532
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.6356
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.2829
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 78290000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 21:18:08.267649
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00297 mins) ***
#
#  best y: 506.175710172675
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.7887
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7314
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.6674
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1562000
#
# *** Simulation 2 / 5 (elapsed time: 0.00533 mins) ***
#
#  best y: 506.175710172675
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.7887
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7314
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.6674
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1562000
#
# *** Simulation 3 / 5 (elapsed time: 0.00961 mins) ***
#
#  best y: 526.233900381994
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.8123
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7216
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.5571
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1514000
#
# *** Simulation 4 / 5 (elapsed time: 0.0126 mins) ***
#
#  best y: 526.233900381994
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.8123
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7216
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.5571
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1514000
#
# *** Simulation 5 / 5 (elapsed time: 0.0143 mins) ***
#
#  best y: 526.233900381994
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.8123
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7216
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.5571
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1514000
#
# *** Simulation 6 / 5 (elapsed time: 0.0183 mins) ***
#
#  best y: 526.233900381994
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.8123
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7216
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.5571
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1514000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 21:18:09.421793
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00251 mins) ***
#
#  best y: 442.878054976877
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.3268
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.1513
# 	 %ALPHA1@sePar01.pc3 = 0.9993
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 233100
#
# *** Simulation 2 / 5 (elapsed time: 0.00469 mins) ***
#
#  best y: 449.592633690123
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1956
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.4695
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9992
# 	 %SIGMA1@wn2.pc3 = 236300
#
# *** Simulation 3 / 5 (elapsed time: 0.00786 mins) ***
#
#  best y: 449.604373403617
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.248
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.5085
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 236300
#
# *** Simulation 4 / 5 (elapsed time: 0.00967 mins) ***
#
#  best y: 449.604373403617
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.248
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.5085
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 236300
#
# *** Simulation 5 / 5 (elapsed time: 0.0111 mins) ***
#
#  best y: 449.604373403617
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.248
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.5085
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 236300
#
# *** Simulation 6 / 5 (elapsed time: 0.0132 mins) ***
#
#  best y: 449.618201892489
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.2624
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.523
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 236300
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 21:18:10.264523
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00144 mins) ***
#
#  best y: 332.412615437576
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 1
# 	 %ALPHA1@sePar01.pc5 = 1
# 	 %SIGMA1@wn1.pc5 = 0.9951
# 	 %SIGMA1@wn2.pc5 = 18750
#
# *** Simulation 2 / 5 (elapsed time: 0.00214 mins) ***
#
#  best y: 332.42806145212
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 1
# 	 %ALPHA1@sePar01.pc5 = 1
# 	 %SIGMA1@wn1.pc5 = 0.9951
# 	 %SIGMA1@wn2.pc5 = 18760
#
# *** Simulation 3 / 5 (elapsed time: 0.00312 mins) ***
#
#  best y: 384.060309884951
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.0005872
# 	 %ALPHA1@sePar01.pc5 = 0.9994
# 	 %SIGMA1@wn1.pc5 = 0.9976
# 	 %SIGMA1@wn2.pc5 = 18730
#
# *** Simulation 4 / 5 (elapsed time: 0.00432 mins) ***
#
#  best y: 384.133271754689
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 4.327e-07
# 	 %ALPHA1@sePar01.pc5 = 0.9994
# 	 %SIGMA1@wn1.pc5 = 0.9977
# 	 %SIGMA1@wn2.pc5 = 18800
#
# *** Simulation 5 / 5 (elapsed time: 0.00552 mins) ***
#
#  best y: 384.133271754689
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 4.327e-07
# 	 %ALPHA1@sePar01.pc5 = 0.9994
# 	 %SIGMA1@wn1.pc5 = 0.9977
# 	 %SIGMA1@wn2.pc5 = 18800
#
# *** Simulation 6 / 5 (elapsed time: 0.00663 mins) ***
#
#  best y: 384.133271754689
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 4.327e-07
# 	 %ALPHA1@sePar01.pc5 = 0.9994
# 	 %SIGMA1@wn1.pc5 = 0.9977
# 	 %SIGMA1@wn2.pc5 = 18800
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 21:18:10.719145
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00111 mins) ***
#
#  best y: 333.101595731347
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 1
# 	 %ALPHA1@sePar01.pc6 = 1
# 	 %SIGMA1@wn1.pc6 = 0.9951
# 	 %SIGMA1@wn2.pc6 = 9924
#
# *** Simulation 2 / 5 (elapsed time: 0.00329 mins) ***
#
#  best y: 373.366930656938
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.03196
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9925
#
# *** Simulation 3 / 5 (elapsed time: 0.00515 mins) ***
#
#  best y: 373.366930656938
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.03196
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9925
#
# *** Simulation 4 / 5 (elapsed time: 0.00608 mins) ***
#
#  best y: 373.366930656938
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.03196
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9925
#
# *** Simulation 5 / 5 (elapsed time: 0.00697 mins) ***
#
#  best y: 373.366930656938
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.03196
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9925
#
# *** Simulation 6 / 5 (elapsed time: 0.00811 mins) ***
#
#  best y: 373.366930656938
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.03196
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9925
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 21:18:11.263739
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00108 mins) ***
#
#  best y: 345.457050024305
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.2909
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9961
# 	 %SIGMA1@wn2.pc7 = 9669
#
# *** Simulation 2 / 5 (elapsed time: 0.00224 mins) ***
#
#  best y: 345.708138198268
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.1531
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9961
# 	 %SIGMA1@wn2.pc7 = 9691
#
# *** Simulation 3 / 5 (elapsed time: 0.00326 mins) ***
#
#  best y: 345.708138198268
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.1531
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9961
# 	 %SIGMA1@wn2.pc7 = 9691
#
# *** Simulation 4 / 5 (elapsed time: 0.00451 mins) ***
#
#  best y: 345.708138198268
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.1531
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9961
# 	 %SIGMA1@wn2.pc7 = 9691
#
# *** Simulation 5 / 5 (elapsed time: 0.0056 mins) ***
#
#  best y: 345.708138198268
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.1531
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.9961
# 	 %SIGMA1@wn2.pc7 = 9691
#
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2025-11-13 21:18:12.945365
#  Number of chains: 1
#  Number of simulations: <until converged>
#
# *** Simulation 5 / <until converged> (elapsed time: 0.0504 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.288e-01    0.1053 4.963e-03      8.461e-03
# e1_natural_ventilation_rate 7.003e-01    0.1008 4.753e-03      1.482e-02
# %SIGMA@wn2*.pc.mu%          1.485e+05 5017.8981 2.365e+02      3.812e+02
# b10_airloophvac             7.126e-01    0.1995 9.402e-03      2.853e-02
# %SIGMA@wn2*.pc1%            1.119e+05 3644.5863 1.718e+02      3.082e+02
# %SIGMA@wn2*.pc2%            2.126e+03   66.0370 3.113e+00      4.244e+00
# %SIGMA@wn2*.pc3%            3.177e+02   10.5201 4.959e-01      9.393e-01
# %SIGMA@wn2*.pc5%            2.620e+01    0.9327 4.397e-02      7.144e-02
# a5_infiltration_rate        1.667e-01    0.1347 6.349e-03      8.809e-03
# %SIGMA@wn2*.pc6%            1.357e+01    0.4548 2.144e-02      3.416e-02
# %SIGMA@wn2*.pc7%            1.346e+01    0.4409 2.078e-02      2.804e-02
#                                    t    eff      s
# d2_htgsp_office_st          0.025734 0.3441 154.83
# e1_natural_ventilation_rate 0.021160 0.1029  46.30
# %SIGMA@wn2*.pc.mu%          0.002568 0.3850 173.25
# b10_airloophvac             0.040033 0.1086  48.88
# %SIGMA@wn2*.pc1%            0.002754 0.3108 139.84
# %SIGMA@wn2*.pc2%            0.001997 0.5380 242.09
# %SIGMA@wn2*.pc3%            0.002957 0.2787 125.43
# %SIGMA@wn2*.pc5%            0.002727 0.3788 170.44
# a5_infiltration_rate        0.052844 0.5195 233.79
# %SIGMA@wn2*.pc6%            0.002517 0.3939 177.28
# %SIGMA@wn2*.pc7%            0.002083 0.5494 247.25
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          9.165e-02 2.668e-01 3.378e-01 4.006e-01 5.141e-01
# e1_natural_ventilation_rate 5.292e-01 6.267e-01 6.985e-01 7.657e-01 9.235e-01
# %SIGMA@wn2*.pc.mu%          1.392e+05 1.448e+05 1.483e+05 1.521e+05 1.583e+05
# b10_airloophvac             3.191e-01 5.517e-01 7.452e-01 8.835e-01 9.939e-01
# %SIGMA@wn2*.pc1%            1.045e+05 1.093e+05 1.121e+05 1.144e+05 1.188e+05
# %SIGMA@wn2*.pc2%            1.999e+03 2.079e+03 2.126e+03 2.167e+03 2.268e+03
# %SIGMA@wn2*.pc3%            2.980e+02 3.111e+02 3.181e+02 3.240e+02 3.388e+02
# %SIGMA@wn2*.pc5%            2.447e+01 2.553e+01 2.617e+01 2.686e+01 2.791e+01
# a5_infiltration_rate        7.770e-03 7.010e-02 1.388e-01 2.232e-01 5.192e-01
# %SIGMA@wn2*.pc6%            1.267e+01 1.327e+01 1.359e+01 1.387e+01 1.449e+01
# %SIGMA@wn2*.pc7%            1.256e+01 1.316e+01 1.347e+01 1.378e+01 1.430e+01
#
# *** Simulation 10 / <until converged> (elapsed time: 0.0857 mins) ***
#
# Iterations = 100:3696
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 900
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.316e-01    0.1037 3.456e-03      5.737e-03
# e1_natural_ventilation_rate 7.102e-01    0.1012 3.374e-03      7.515e-03
# %SIGMA@wn2*.pc.mu%          1.482e+05 4823.6000 1.608e+02      2.082e+02
# b10_airloophvac             7.210e-01    0.2077 6.925e-03      1.891e-02
# %SIGMA@wn2*.pc1%            1.120e+05 3559.4695 1.186e+02      1.432e+02
# %SIGMA@wn2*.pc2%            2.121e+03   67.6309 2.254e+00      2.811e+00
# %SIGMA@wn2*.pc3%            3.194e+02   10.4863 3.495e-01      4.738e-01
# %SIGMA@wn2*.pc5%            2.617e+01    0.8785 2.928e-02      3.722e-02
# a5_infiltration_rate        1.816e-01    0.1467 4.892e-03      7.075e-03
# %SIGMA@wn2*.pc6%            1.361e+01    0.4567 1.522e-02      2.183e-02
# %SIGMA@wn2*.pc7%            1.348e+01    0.4414 1.471e-02      1.790e-02
#                                    t    eff     s
# d2_htgsp_office_st          0.017301 0.3628 326.5
# e1_natural_ventilation_rate 0.010582 0.2016 181.4
# %SIGMA@wn2*.pc.mu%          0.001405 0.5964 536.8
# b10_airloophvac             0.026228 0.1341 120.7
# %SIGMA@wn2*.pc1%            0.001279 0.6861 617.5
# %SIGMA@wn2*.pc2%            0.001325 0.6433 579.0
# %SIGMA@wn2*.pc3%            0.001484 0.5442 489.8
# %SIGMA@wn2*.pc5%            0.001422 0.6189 557.0
# a5_infiltration_rate        0.038967 0.4781 430.3
# %SIGMA@wn2*.pc6%            0.001605 0.4860 437.4
# %SIGMA@wn2*.pc7%            0.001328 0.6755 608.0
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          1.000e-01 2.655e-01 3.393e-01 4.039e-01 5.149e-01
# e1_natural_ventilation_rate 5.310e-01 6.411e-01 7.090e-01 7.740e-01 9.417e-01
# %SIGMA@wn2*.pc.mu%          1.392e+05 1.448e+05 1.482e+05 1.515e+05 1.580e+05
# b10_airloophvac             3.004e-01 5.772e-01 7.557e-01 9.038e-01 9.930e-01
# %SIGMA@wn2*.pc1%            1.049e+05 1.095e+05 1.120e+05 1.144e+05 1.187e+05
# %SIGMA@wn2*.pc2%            1.998e+03 2.074e+03 2.120e+03 2.166e+03 2.255e+03
# %SIGMA@wn2*.pc3%            2.996e+02 3.125e+02 3.190e+02 3.257e+02 3.407e+02
# %SIGMA@wn2*.pc5%            2.458e+01 2.554e+01 2.615e+01 2.677e+01 2.790e+01
# a5_infiltration_rate        7.863e-03 7.889e-02 1.534e-01 2.370e-01 5.431e-01
# %SIGMA@wn2*.pc6%            1.272e+01 1.331e+01 1.359e+01 1.389e+01 1.457e+01
# %SIGMA@wn2*.pc7%            1.257e+01 1.318e+01 1.348e+01 1.378e+01 1.434e+01
#
# *** Simulation 15 / <until converged> (elapsed time: 0.121 mins) ***
#
# Iterations = 150:5546
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 1350
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.300e-01    0.1047 2.850e-03      4.433e-03
# e1_natural_ventilation_rate 7.172e-01    0.1016 2.765e-03      6.240e-03
# %SIGMA@wn2*.pc.mu%          1.482e+05 4876.0121 1.327e+02      1.455e+02
# b10_airloophvac             7.345e-01    0.2079 5.659e-03      1.380e-02
# %SIGMA@wn2*.pc1%            1.120e+05 3620.1627 9.853e+01      1.095e+02
# %SIGMA@wn2*.pc2%            2.122e+03   68.2095 1.856e+00      2.304e+00
# %SIGMA@wn2*.pc3%            3.191e+02   10.4510 2.844e-01      3.569e-01
# %SIGMA@wn2*.pc5%            2.616e+01    0.8568 2.332e-02      2.752e-02
# a5_infiltration_rate        1.829e-01    0.1547 4.211e-03      7.385e-03
# %SIGMA@wn2*.pc6%            1.363e+01    0.4515 1.229e-02      1.452e-02
# %SIGMA@wn2*.pc7%            1.348e+01    0.4423 1.204e-02      1.395e-02
#                                     t    eff      s
# d2_htgsp_office_st          0.0134340 0.4134  558.1
# e1_natural_ventilation_rate 0.0087016 0.1964  265.1
# %SIGMA@wn2*.pc.mu%          0.0009818 0.8317 1122.8
# b10_airloophvac             0.0187900 0.1681  227.0
# %SIGMA@wn2*.pc1%            0.0009780 0.8095 1092.8
# %SIGMA@wn2*.pc2%            0.0010855 0.6494  876.7
# %SIGMA@wn2*.pc3%            0.0011186 0.6351  857.4
# %SIGMA@wn2*.pc5%            0.0010519 0.7181  969.4
# a5_infiltration_rate        0.0403693 0.3251  438.9
# %SIGMA@wn2*.pc6%            0.0010656 0.7161  966.8
# %SIGMA@wn2*.pc7%            0.0010347 0.7448 1005.5
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          9.504e-02 2.634e-01 3.351e-01 4.042e-01 5.140e-01
# e1_natural_ventilation_rate 5.319e-01 6.473e-01 7.148e-01 7.808e-01 9.441e-01
# %SIGMA@wn2*.pc.mu%          1.391e+05 1.448e+05 1.481e+05 1.516e+05 1.580e+05
# b10_airloophvac             3.052e-01 5.951e-01 7.702e-01 9.215e-01 9.945e-01
# %SIGMA@wn2*.pc1%            1.047e+05 1.095e+05 1.120e+05 1.144e+05 1.191e+05
# %SIGMA@wn2*.pc2%            1.997e+03 2.075e+03 2.120e+03 2.166e+03 2.263e+03
# %SIGMA@wn2*.pc3%            2.994e+02 3.121e+02 3.192e+02 3.256e+02 3.404e+02
# %SIGMA@wn2*.pc5%            2.455e+01 2.559e+01 2.618e+01 2.672e+01 2.784e+01
# a5_infiltration_rate        7.978e-03 7.295e-02 1.489e-01 2.409e-01 5.914e-01
# %SIGMA@wn2*.pc6%            1.275e+01 1.332e+01 1.361e+01 1.393e+01 1.455e+01
# %SIGMA@wn2*.pc7%            1.262e+01 1.319e+01 1.347e+01 1.378e+01 1.435e+01
#
# *** Simulation 20 / <until converged> (elapsed time: 0.156 mins) ***
#
# Iterations = 200:7396
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 1800
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.287e-01    0.1051 2.478e-03      3.991e-03
# e1_natural_ventilation_rate 7.198e-01    0.1032 2.433e-03      5.435e-03
# %SIGMA@wn2*.pc.mu%          1.483e+05 4873.6015 1.149e+02      1.163e+02
# b10_airloophvac             7.389e-01    0.2105 4.962e-03      1.287e-02
# %SIGMA@wn2*.pc1%            1.120e+05 3669.2415 8.648e+01      9.594e+01
# %SIGMA@wn2*.pc2%            2.122e+03   68.9164 1.624e+00      1.959e+00
# %SIGMA@wn2*.pc3%            3.190e+02   10.2985 2.427e-01      2.843e-01
# %SIGMA@wn2*.pc5%            2.618e+01    0.8465 1.995e-02      2.347e-02
# a5_infiltration_rate        1.835e-01    0.1536 3.621e-03      5.528e-03
# %SIGMA@wn2*.pc6%            1.364e+01    0.4452 1.049e-02      1.229e-02
# %SIGMA@wn2*.pc7%            1.348e+01    0.4354 1.026e-02      1.102e-02
#                                     t    eff      s
# d2_htgsp_office_st          0.0121421 0.3856  694.2
# e1_natural_ventilation_rate 0.0075508 0.2004  360.7
# %SIGMA@wn2*.pc.mu%          0.0007847 0.9748 1754.7
# b10_airloophvac             0.0174129 0.1487  267.7
# %SIGMA@wn2*.pc1%            0.0008567 0.8126 1462.7
# %SIGMA@wn2*.pc2%            0.0009233 0.6875 1237.5
# %SIGMA@wn2*.pc3%            0.0008911 0.7290 1312.3
# %SIGMA@wn2*.pc5%            0.0008965 0.7228 1301.0
# a5_infiltration_rate        0.0301294 0.4291  772.4
# %SIGMA@wn2*.pc6%            0.0009013 0.7288 1311.9
# %SIGMA@wn2*.pc7%            0.0008173 0.8669 1560.3
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          9.286e-02 2.623e-01 3.336e-01 3.994e-01 5.142e-01
# e1_natural_ventilation_rate 5.361e-01 6.478e-01 7.158e-01 7.857e-01 9.467e-01
# %SIGMA@wn2*.pc.mu%          1.391e+05 1.449e+05 1.482e+05 1.517e+05 1.579e+05
# b10_airloophvac             3.058e-01 6.002e-01 7.752e-01 9.284e-01 9.954e-01
# %SIGMA@wn2*.pc1%            1.047e+05 1.095e+05 1.119e+05 1.144e+05 1.192e+05
# %SIGMA@wn2*.pc2%            1.997e+03 2.074e+03 2.119e+03 2.167e+03 2.264e+03
# %SIGMA@wn2*.pc3%            2.991e+02 3.121e+02 3.190e+02 3.256e+02 3.397e+02
# %SIGMA@wn2*.pc5%            2.458e+01 2.562e+01 2.619e+01 2.671e+01 2.782e+01
# a5_infiltration_rate        7.722e-03 7.177e-02 1.499e-01 2.441e-01 5.821e-01
# %SIGMA@wn2*.pc6%            1.278e+01 1.334e+01 1.362e+01 1.394e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.265e+01 1.320e+01 1.348e+01 1.378e+01 1.434e+01
#
# *** Simulation 25 / <until converged> (elapsed time: 0.192 mins) ***
#
# Iterations = 250:9246
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 2250
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.285e-01    0.1048 2.210e-03      3.590e-03
# e1_natural_ventilation_rate 7.202e-01    0.1047 2.208e-03      4.945e-03
# %SIGMA@wn2*.pc.mu%          1.483e+05 4831.2538 1.019e+02      1.227e+02
# b10_airloophvac             7.402e-01    0.2116 4.461e-03      1.103e-02
# %SIGMA@wn2*.pc1%            1.120e+05 3627.5895 7.648e+01      8.562e+01
# %SIGMA@wn2*.pc2%            2.121e+03   68.3831 1.442e+00      1.713e+00
# %SIGMA@wn2*.pc3%            3.190e+02   10.2779 2.167e-01      2.545e-01
# %SIGMA@wn2*.pc5%            2.617e+01    0.8356 1.762e-02      2.083e-02
# a5_infiltration_rate        1.852e-01    0.1543 3.254e-03      4.983e-03
# %SIGMA@wn2*.pc6%            1.364e+01    0.4501 9.489e-03      1.102e-02
# %SIGMA@wn2*.pc7%            1.349e+01    0.4347 9.165e-03      9.915e-03
#                                     t    eff      s
# d2_htgsp_office_st          0.0109301 0.3788  852.3
# e1_natural_ventilation_rate 0.0068662 0.1993  448.3
# %SIGMA@wn2*.pc.mu%          0.0008276 0.6891 1550.4
# b10_airloophvac             0.0148941 0.1637  368.3
# %SIGMA@wn2*.pc1%            0.0007641 0.7979 1795.2
# %SIGMA@wn2*.pc2%            0.0008076 0.7080 1593.0
# %SIGMA@wn2*.pc3%            0.0007978 0.7248 1630.7
# %SIGMA@wn2*.pc5%            0.0007961 0.7151 1609.0
# a5_infiltration_rate        0.0269113 0.4263  959.2
# %SIGMA@wn2*.pc6%            0.0008081 0.7412 1667.7
# %SIGMA@wn2*.pc7%            0.0007351 0.8543 1922.2
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          9.222e-02 2.634e-01 3.336e-01 3.988e-01 5.141e-01
# e1_natural_ventilation_rate 5.323e-01 6.466e-01 7.162e-01 7.859e-01 9.514e-01
# %SIGMA@wn2*.pc.mu%          1.392e+05 1.450e+05 1.481e+05 1.517e+05 1.577e+05
# b10_airloophvac             2.995e-01 6.031e-01 7.812e-01 9.309e-01 9.954e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.995e+03 2.074e+03 2.120e+03 2.168e+03 2.260e+03
# %SIGMA@wn2*.pc3%            2.993e+02 3.120e+02 3.189e+02 3.256e+02 3.398e+02
# %SIGMA@wn2*.pc5%            2.457e+01 2.560e+01 2.619e+01 2.670e+01 2.779e+01
# a5_infiltration_rate        7.791e-03 7.468e-02 1.489e-01 2.509e-01 5.740e-01
# %SIGMA@wn2*.pc6%            1.276e+01 1.334e+01 1.362e+01 1.395e+01 1.454e+01
# %SIGMA@wn2*.pc7%            1.265e+01 1.319e+01 1.348e+01 1.378e+01 1.435e+01
#
# *** Simulation 30 / <until converged> (elapsed time: 0.228 mins) ***
#
# Iterations = 300:11096
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 2700
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.276e-01    0.1054  0.002028       0.003357
# e1_natural_ventilation_rate 7.224e-01    0.1055  0.002030       0.004694
# %SIGMA@wn2*.pc.mu%          1.482e+05 4795.8848 92.296847      99.151187
# b10_airloophvac             7.443e-01    0.2102  0.004045       0.010512
# %SIGMA@wn2*.pc1%            1.120e+05 3650.6264 70.256338      78.365108
# %SIGMA@wn2*.pc2%            2.122e+03   68.5957  1.320125       1.592709
# %SIGMA@wn2*.pc3%            3.189e+02   10.2055  0.196404       0.231159
# %SIGMA@wn2*.pc5%            2.616e+01    0.8368  0.016103       0.018932
# a5_infiltration_rate        1.852e-01    0.1551  0.002986       0.004511
# %SIGMA@wn2*.pc6%            1.364e+01    0.4489  0.008638       0.010055
# %SIGMA@wn2*.pc7%            1.349e+01    0.4353  0.008377       0.009317
#                                     t    eff      s
# d2_htgsp_office_st          0.0102473 0.3650  985.5
# e1_natural_ventilation_rate 0.0064989 0.1870  504.9
# %SIGMA@wn2*.pc.mu%          0.0006691 0.8665 2339.6
# b10_airloophvac             0.0141242 0.1481  399.8
# %SIGMA@wn2*.pc1%            0.0006994 0.8038 2170.1
# %SIGMA@wn2*.pc2%            0.0007505 0.6870 1854.9
# %SIGMA@wn2*.pc3%            0.0007249 0.7219 1949.1
# %SIGMA@wn2*.pc5%            0.0007236 0.7235 1953.4
# a5_infiltration_rate        0.0243537 0.4380 1182.6
# %SIGMA@wn2*.pc6%            0.0007370 0.7381 1992.9
# %SIGMA@wn2*.pc7%            0.0006908 0.8083 2182.4
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          9.255e-02 2.598e-01 3.326e-01 3.997e-01 5.134e-01
# e1_natural_ventilation_rate 5.316e-01 6.490e-01 7.181e-01 7.881e-01 9.559e-01
# %SIGMA@wn2*.pc.mu%          1.391e+05 1.450e+05 1.480e+05 1.516e+05 1.576e+05
# b10_airloophvac             3.037e-01 6.055e-01 7.841e-01 9.347e-01 9.954e-01
# %SIGMA@wn2*.pc1%            1.048e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.995e+03 2.075e+03 2.121e+03 2.169e+03 2.259e+03
# %SIGMA@wn2*.pc3%            2.997e+02 3.119e+02 3.186e+02 3.255e+02 3.396e+02
# %SIGMA@wn2*.pc5%            2.456e+01 2.559e+01 2.618e+01 2.671e+01 2.782e+01
# a5_infiltration_rate        7.791e-03 7.379e-02 1.497e-01 2.466e-01 6.011e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.334e+01 1.363e+01 1.394e+01 1.456e+01
# %SIGMA@wn2*.pc7%            1.265e+01 1.319e+01 1.348e+01 1.378e+01 1.434e+01
#
# *** Simulation 35 / <until converged> (elapsed time: 0.263 mins) ***
#
# Iterations = 350:12946
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 3150
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.252e-01    0.1063  0.001894       0.003162
# e1_natural_ventilation_rate 7.253e-01    0.1058  0.001885       0.004527
# %SIGMA@wn2*.pc.mu%          1.481e+05 4747.8319 84.594096      84.649915
# b10_airloophvac             7.521e-01    0.2073  0.003693       0.009525
# %SIGMA@wn2*.pc1%            1.120e+05 3645.0676 64.945687      76.319237
# %SIGMA@wn2*.pc2%            2.122e+03   67.9020  1.209838       1.456763
# %SIGMA@wn2*.pc3%            3.187e+02   10.2570  0.182753       0.217040
# %SIGMA@wn2*.pc5%            2.617e+01    0.8428  0.015016       0.018601
# a5_infiltration_rate        1.832e-01    0.1529  0.002724       0.004040
# %SIGMA@wn2*.pc6%            1.364e+01    0.4480  0.007982       0.009210
# %SIGMA@wn2*.pc7%            1.349e+01    0.4366  0.007779       0.008970
#                                     t    eff      s
# d2_htgsp_office_st          0.0097253 0.3585 1129.4
# e1_natural_ventilation_rate 0.0062416 0.1734  546.1
# %SIGMA@wn2*.pc.mu%          0.0005714 0.9987 3145.8
# b10_airloophvac             0.0126658 0.1503  473.6
# %SIGMA@wn2*.pc1%            0.0006811 0.7242 2281.1
# %SIGMA@wn2*.pc2%            0.0006864 0.6897 2172.6
# %SIGMA@wn2*.pc3%            0.0006810 0.7090 2233.3
# %SIGMA@wn2*.pc5%            0.0007109 0.6516 2052.6
# a5_infiltration_rate        0.0220555 0.4545 1431.7
# %SIGMA@wn2*.pc6%            0.0006751 0.7511 2366.0
# %SIGMA@wn2*.pc7%            0.0006648 0.7521 2369.2
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.783e-02 2.577e-01 3.313e-01 3.977e-01 5.134e-01
# e1_natural_ventilation_rate 5.320e-01 6.522e-01 7.226e-01 7.916e-01 9.583e-01
# %SIGMA@wn2*.pc.mu%          1.391e+05 1.450e+05 1.480e+05 1.515e+05 1.573e+05
# b10_airloophvac             3.154e-01 6.178e-01 7.894e-01 9.395e-01 9.961e-01
# %SIGMA@wn2*.pc1%            1.049e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.994e+03 2.075e+03 2.121e+03 2.169e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.993e+02 3.117e+02 3.185e+02 3.254e+02 3.396e+02
# %SIGMA@wn2*.pc5%            2.457e+01 2.559e+01 2.618e+01 2.672e+01 2.784e+01
# a5_infiltration_rate        7.791e-03 7.391e-02 1.490e-01 2.412e-01 5.828e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.363e+01 1.395e+01 1.455e+01
# %SIGMA@wn2*.pc7%            1.264e+01 1.320e+01 1.348e+01 1.379e+01 1.434e+01
#
# *** Simulation 40 / <until converged> (elapsed time: 0.299 mins) ***
#
# Iterations = 400:14796
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 3600
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.232e-01    0.1065  0.001775       0.002966
# e1_natural_ventilation_rate 7.270e-01    0.1054  0.001756       0.004266
# %SIGMA@wn2*.pc.mu%          1.482e+05 4732.4870 78.874784      79.131202
# b10_airloophvac             7.565e-01    0.2055  0.003424       0.009002
# %SIGMA@wn2*.pc1%            1.121e+05 3626.8235 60.447059      71.368550
# %SIGMA@wn2*.pc2%            2.123e+03   68.3856  1.139760       1.457810
# %SIGMA@wn2*.pc3%            3.186e+02   10.3313  0.172188       0.202520
# %SIGMA@wn2*.pc5%            2.616e+01    0.8440  0.014067       0.017341
# a5_infiltration_rate        1.823e-01    0.1522  0.002537       0.003777
# %SIGMA@wn2*.pc6%            1.364e+01    0.4471  0.007451       0.008649
# %SIGMA@wn2*.pc7%            1.350e+01    0.4374  0.007289       0.008498
#                                     t    eff      s
# d2_htgsp_office_st          0.0091756 0.3582 1289.4
# e1_natural_ventilation_rate 0.0058676 0.1696  610.4
# %SIGMA@wn2*.pc.mu%          0.0005341 0.9935 3576.7
# b10_airloophvac             0.0118996 0.1447  520.9
# %SIGMA@wn2*.pc1%            0.0006367 0.7174 2582.5
# %SIGMA@wn2*.pc2%            0.0006868 0.6113 2200.5
# %SIGMA@wn2*.pc3%            0.0006356 0.7229 2602.4
# %SIGMA@wn2*.pc5%            0.0006629 0.6580 2368.9
# a5_infiltration_rate        0.0207135 0.4510 1623.6
# %SIGMA@wn2*.pc6%            0.0006341 0.7421 2671.7
# %SIGMA@wn2*.pc7%            0.0006297 0.7358 2648.7
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.669e-02 2.561e-01 3.285e-01 3.965e-01 5.135e-01
# e1_natural_ventilation_rate 5.342e-01 6.539e-01 7.249e-01 7.924e-01 9.602e-01
# %SIGMA@wn2*.pc.mu%          1.391e+05 1.450e+05 1.481e+05 1.514e+05 1.574e+05
# b10_airloophvac             3.231e-01 6.232e-01 7.952e-01 9.421e-01 9.964e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.195e+05
# %SIGMA@wn2*.pc2%            1.994e+03 2.074e+03 2.122e+03 2.169e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.991e+02 3.117e+02 3.183e+02 3.252e+02 3.397e+02
# %SIGMA@wn2*.pc5%            2.456e+01 2.559e+01 2.618e+01 2.672e+01 2.782e+01
# a5_infiltration_rate        7.722e-03 7.257e-02 1.485e-01 2.408e-01 5.724e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.362e+01 1.394e+01 1.455e+01
# %SIGMA@wn2*.pc7%            1.265e+01 1.320e+01 1.349e+01 1.379e+01 1.436e+01
#
# *** Simulation 45 / <until converged> (elapsed time: 0.334 mins) ***
#
# Iterations = 450:16646
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 4050
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.226e-01    0.1061  0.001667       0.002762
# e1_natural_ventilation_rate 7.267e-01    0.1053  0.001655       0.004025
# %SIGMA@wn2*.pc.mu%          1.482e+05 4796.9036 75.376069      84.988942
# b10_airloophvac             7.574e-01    0.2030  0.003190       0.008507
# %SIGMA@wn2*.pc1%            1.120e+05 3625.2884 56.965912      67.052767
# %SIGMA@wn2*.pc2%            2.122e+03   68.7914  1.080953       1.303280
# %SIGMA@wn2*.pc3%            3.185e+02   10.4090  0.163562       0.194229
# %SIGMA@wn2*.pc5%            2.617e+01    0.8338  0.013102       0.015687
# a5_infiltration_rate        1.854e-01    0.1557  0.002447       0.003693
# %SIGMA@wn2*.pc6%            1.364e+01    0.4499  0.007070       0.008437
# %SIGMA@wn2*.pc7%            1.350e+01    0.4418  0.006942       0.008220
#                                     t    eff      s
# d2_htgsp_office_st          0.0085627 0.3640 1474.4
# e1_natural_ventilation_rate 0.0055393 0.1690  684.4
# %SIGMA@wn2*.pc.mu%          0.0005735 0.7866 3185.6
# b10_airloophvac             0.0112321 0.1406  569.3
# %SIGMA@wn2*.pc1%            0.0005985 0.7218 2923.2
# %SIGMA@wn2*.pc2%            0.0006142 0.6879 2786.1
# %SIGMA@wn2*.pc3%            0.0006099 0.7091 2872.0
# %SIGMA@wn2*.pc5%            0.0005995 0.6976 2825.2
# a5_infiltration_rate        0.0199138 0.4391 1778.3
# %SIGMA@wn2*.pc6%            0.0006185 0.7022 2843.8
# %SIGMA@wn2*.pc7%            0.0006089 0.7133 2888.9
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.590e-02 2.561e-01 3.283e-01 3.960e-01 5.124e-01
# e1_natural_ventilation_rate 5.335e-01 6.539e-01 7.245e-01 7.909e-01 9.594e-01
# %SIGMA@wn2*.pc.mu%          1.390e+05 1.450e+05 1.481e+05 1.515e+05 1.577e+05
# b10_airloophvac             3.297e-01 6.278e-01 7.947e-01 9.402e-01 9.965e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.119e+05 1.144e+05 1.194e+05
# %SIGMA@wn2*.pc2%            1.990e+03 2.074e+03 2.122e+03 2.169e+03 2.258e+03
# %SIGMA@wn2*.pc3%            2.986e+02 3.113e+02 3.182e+02 3.252e+02 3.396e+02
# %SIGMA@wn2*.pc5%            2.456e+01 2.560e+01 2.618e+01 2.673e+01 2.780e+01
# a5_infiltration_rate        8.078e-03 7.504e-02 1.484e-01 2.462e-01 5.889e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.362e+01 1.395e+01 1.455e+01
# %SIGMA@wn2*.pc7%            1.264e+01 1.320e+01 1.349e+01 1.380e+01 1.437e+01
#
# *** Simulation 50 / <until converged> (elapsed time: 0.37 mins) ***
#
# Iterations = 500:18496
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 4500
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.226e-01    0.1056  0.001574       0.002571
# e1_natural_ventilation_rate 7.251e-01    0.1054  0.001571       0.003805
# %SIGMA@wn2*.pc.mu%          1.482e+05 4808.0720 71.674505      76.913910
# b10_airloophvac             7.544e-01    0.2031  0.003028       0.007899
# %SIGMA@wn2*.pc1%            1.120e+05 3666.8941 54.662829      64.703366
# %SIGMA@wn2*.pc2%            2.122e+03   68.4252  1.020023       1.230685
# %SIGMA@wn2*.pc3%            3.185e+02   10.4184  0.155309       0.182064
# %SIGMA@wn2*.pc5%            2.616e+01    0.8374  0.012483       0.015058
# a5_infiltration_rate        1.857e-01    0.1564  0.002332       0.003564
# %SIGMA@wn2*.pc6%            1.364e+01    0.4515  0.006730       0.008139
# %SIGMA@wn2*.pc7%            1.350e+01    0.4395  0.006551       0.007487
#                                     t    eff      s
# d2_htgsp_office_st          0.0079678 0.3747 1686.1
# e1_natural_ventilation_rate 0.0052472 0.1705  767.3
# %SIGMA@wn2*.pc.mu%          0.0005190 0.8684 3907.8
# b10_airloophvac             0.0104709 0.1470  661.3
# %SIGMA@wn2*.pc1%            0.0005776 0.7137 3211.8
# %SIGMA@wn2*.pc2%            0.0005800 0.6870 3091.3
# %SIGMA@wn2*.pc3%            0.0005716 0.7277 3274.6
# %SIGMA@wn2*.pc5%            0.0005756 0.6872 3092.4
# a5_infiltration_rate        0.0191965 0.4281 1926.3
# %SIGMA@wn2*.pc6%            0.0005968 0.6839 3077.5
# %SIGMA@wn2*.pc7%            0.0005546 0.7655 3444.9
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.710e-02 2.562e-01 3.285e-01 3.953e-01 5.093e-01
# e1_natural_ventilation_rate 5.316e-01 6.523e-01 7.214e-01 7.903e-01 9.578e-01
# %SIGMA@wn2*.pc.mu%          1.390e+05 1.450e+05 1.481e+05 1.515e+05 1.577e+05
# b10_airloophvac             3.228e-01 6.231e-01 7.905e-01 9.387e-01 9.961e-01
# %SIGMA@wn2*.pc1%            1.049e+05 1.096e+05 1.119e+05 1.144e+05 1.195e+05
# %SIGMA@wn2*.pc2%            1.990e+03 2.074e+03 2.121e+03 2.168e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.988e+02 3.114e+02 3.182e+02 3.254e+02 3.395e+02
# %SIGMA@wn2*.pc5%            2.456e+01 2.560e+01 2.617e+01 2.673e+01 2.780e+01
# a5_infiltration_rate        7.782e-03 7.447e-02 1.479e-01 2.474e-01 6.045e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.362e+01 1.394e+01 1.456e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.320e+01 1.349e+01 1.380e+01 1.437e+01
#
# *** Simulation 55 / <until converged> (elapsed time: 0.406 mins) ***
#
# Iterations = 550:20346
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 4950
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.231e-01    0.1058  0.001504       0.002461
# e1_natural_ventilation_rate 7.240e-01    0.1049  0.001491       0.003622
# %SIGMA@wn2*.pc.mu%          1.482e+05 4828.8887 68.634836      79.356758
# b10_airloophvac             7.523e-01    0.2027  0.002882       0.007492
# %SIGMA@wn2*.pc1%            1.120e+05 3654.6157 51.944446      59.861586
# %SIGMA@wn2*.pc2%            2.122e+03   68.3414  0.971362       1.159030
# %SIGMA@wn2*.pc3%            3.185e+02   10.3250  0.146753       0.173360
# %SIGMA@wn2*.pc5%            2.617e+01    0.8422  0.011970       0.014509
# a5_infiltration_rate        1.864e-01    0.1572  0.002234       0.003412
# %SIGMA@wn2*.pc6%            1.364e+01    0.4507  0.006405       0.007641
# %SIGMA@wn2*.pc7%            1.350e+01    0.4364  0.006203       0.007130
#                                     t    eff      s
# d2_htgsp_office_st          0.0076159 0.3736 1849.3
# e1_natural_ventilation_rate 0.0050030 0.1695  838.9
# %SIGMA@wn2*.pc.mu%          0.0005356 0.7480 3702.8
# b10_airloophvac             0.0099597 0.1479  732.2
# %SIGMA@wn2*.pc1%            0.0005344 0.7530 3727.2
# %SIGMA@wn2*.pc2%            0.0005463 0.7024 3476.8
# %SIGMA@wn2*.pc3%            0.0005443 0.7166 3547.1
# %SIGMA@wn2*.pc5%            0.0005545 0.6806 3369.1
# a5_infiltration_rate        0.0183039 0.4288 2122.4
# %SIGMA@wn2*.pc6%            0.0005603 0.7027 3478.3
# %SIGMA@wn2*.pc7%            0.0005282 0.7568 3746.0
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.805e-02 2.561e-01 3.292e-01 3.959e-01 5.118e-01
# e1_natural_ventilation_rate 5.335e-01 6.505e-01 7.198e-01 7.889e-01 9.571e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.480e+05 1.515e+05 1.577e+05
# b10_airloophvac             3.230e-01 6.184e-01 7.871e-01 9.360e-01 9.960e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.095e+05 1.119e+05 1.144e+05 1.194e+05
# %SIGMA@wn2*.pc2%            1.989e+03 2.074e+03 2.121e+03 2.168e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.989e+02 3.115e+02 3.182e+02 3.252e+02 3.394e+02
# %SIGMA@wn2*.pc5%            2.456e+01 2.560e+01 2.617e+01 2.674e+01 2.782e+01
# a5_infiltration_rate        7.791e-03 7.504e-02 1.479e-01 2.484e-01 6.078e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.362e+01 1.394e+01 1.455e+01
# %SIGMA@wn2*.pc7%            1.267e+01 1.320e+01 1.349e+01 1.380e+01 1.436e+01
#
# *** Simulation 60 / <until converged> (elapsed time: 0.442 mins) ***
#
# Iterations = 600:22196
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 5400
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.243e-01    0.1063  0.001447       0.002361
# e1_natural_ventilation_rate 7.235e-01    0.1054  0.001435       0.003480
# %SIGMA@wn2*.pc.mu%          1.482e+05 4843.3617 65.909805      79.778912
# b10_airloophvac             7.505e-01    0.2041  0.002777       0.007059
# %SIGMA@wn2*.pc1%            1.120e+05 3652.3560 49.702270      57.379415
# %SIGMA@wn2*.pc2%            2.121e+03   68.0054  0.925437       1.091997
# %SIGMA@wn2*.pc3%            3.184e+02   10.3125  0.140335       0.167679
# %SIGMA@wn2*.pc5%            2.617e+01    0.8407  0.011440       0.013813
# a5_infiltration_rate        1.863e-01    0.1571  0.002138       0.003289
# %SIGMA@wn2*.pc6%            1.364e+01    0.4491  0.006111       0.007391
# %SIGMA@wn2*.pc7%            1.350e+01    0.4345  0.005912       0.006853
#                                     t    eff      s
# d2_htgsp_office_st          0.0072787 0.3757 2028.7
# e1_natural_ventilation_rate 0.0048095 0.1700  918.1
# %SIGMA@wn2*.pc.mu%          0.0005384 0.6825 3685.7
# b10_airloophvac             0.0094059 0.1548  836.0
# %SIGMA@wn2*.pc1%            0.0005122 0.7503 4051.7
# %SIGMA@wn2*.pc2%            0.0005148 0.7182 3878.3
# %SIGMA@wn2*.pc3%            0.0005266 0.7004 3782.4
# %SIGMA@wn2*.pc5%            0.0005279 0.6859 3703.7
# a5_infiltration_rate        0.0176579 0.4223 2280.7
# %SIGMA@wn2*.pc6%            0.0005420 0.6835 3691.1
# %SIGMA@wn2*.pc7%            0.0005076 0.7443 4019.0
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.607e-02 2.566e-01 3.304e-01 3.966e-01 5.129e-01
# e1_natural_ventilation_rate 5.301e-01 6.503e-01 7.196e-01 7.891e-01 9.571e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.481e+05 1.516e+05 1.577e+05
# b10_airloophvac             3.119e-01 6.157e-01 7.870e-01 9.337e-01 9.955e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.119e+05 1.144e+05 1.194e+05
# %SIGMA@wn2*.pc2%            1.989e+03 2.074e+03 2.120e+03 2.167e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.988e+02 3.115e+02 3.181e+02 3.252e+02 3.395e+02
# %SIGMA@wn2*.pc5%            2.455e+01 2.560e+01 2.617e+01 2.673e+01 2.782e+01
# a5_infiltration_rate        7.836e-03 7.472e-02 1.474e-01 2.506e-01 6.053e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.363e+01 1.394e+01 1.454e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.320e+01 1.349e+01 1.379e+01 1.436e+01
#
# *** Simulation 65 / <until converged> (elapsed time: 0.478 mins) ***
#
# Iterations = 650:24046
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 5850
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.244e-01    0.1060  0.001386       0.002270
# e1_natural_ventilation_rate 7.243e-01    0.1052  0.001375       0.003301
# %SIGMA@wn2*.pc.mu%          1.481e+05 4834.8644 63.212995      76.083166
# b10_airloophvac             7.519e-01    0.2030  0.002654       0.006756
# %SIGMA@wn2*.pc1%            1.120e+05 3652.4237 47.753281      56.412784
# %SIGMA@wn2*.pc2%            2.121e+03   67.9408  0.888285       1.053401
# %SIGMA@wn2*.pc3%            3.184e+02   10.3159  0.134874       0.160304
# %SIGMA@wn2*.pc5%            2.616e+01    0.8454  0.011053       0.013188
# a5_infiltration_rate        1.861e-01    0.1566  0.002048       0.003135
# %SIGMA@wn2*.pc6%            1.363e+01    0.4476  0.005852       0.007036
# %SIGMA@wn2*.pc7%            1.350e+01    0.4344  0.005680       0.006782
#                                     t    eff      s
# d2_htgsp_office_st          0.0069984 0.3727 2180.3
# e1_natural_ventilation_rate 0.0045577 0.1735 1015.2
# %SIGMA@wn2*.pc.mu%          0.0005136 0.6903 4038.2
# b10_airloophvac             0.0089854 0.1543  902.4
# %SIGMA@wn2*.pc1%            0.0005036 0.7166 4191.9
# %SIGMA@wn2*.pc2%            0.0004967 0.7111 4159.8
# %SIGMA@wn2*.pc3%            0.0005034 0.7079 4141.2
# %SIGMA@wn2*.pc5%            0.0005041 0.7024 4109.3
# a5_infiltration_rate        0.0168473 0.4266 2495.5
# %SIGMA@wn2*.pc6%            0.0005161 0.6918 4046.8
# %SIGMA@wn2*.pc7%            0.0005023 0.7013 4102.7
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.690e-02 2.576e-01 3.296e-01 3.964e-01 5.133e-01
# e1_natural_ventilation_rate 5.335e-01 6.516e-01 7.204e-01 7.897e-01 9.573e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.480e+05 1.515e+05 1.577e+05
# b10_airloophvac             3.155e-01 6.214e-01 7.885e-01 9.337e-01 9.958e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.095e+05 1.119e+05 1.144e+05 1.195e+05
# %SIGMA@wn2*.pc2%            1.989e+03 2.074e+03 2.120e+03 2.166e+03 2.256e+03
# %SIGMA@wn2*.pc3%            2.988e+02 3.115e+02 3.181e+02 3.252e+02 3.395e+02
# %SIGMA@wn2*.pc5%            2.454e+01 2.559e+01 2.616e+01 2.673e+01 2.782e+01
# ...
# %SIGMA@wn2*.pc6%            0.0003309 0.7131 9626
# %SIGMA@wn2*.pc7%            0.0003309 0.7057 9527
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.208e-02 2.611e-01 3.321e-01 3.987e-01 5.177e-01
# e1_natural_ventilation_rate 5.365e-01 6.567e-01 7.231e-01 7.926e-01 9.551e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.480e+05 1.513e+05 1.576e+05
# b10_airloophvac             3.149e-01 6.270e-01 7.936e-01 9.375e-01 9.963e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.073e+03 2.119e+03 2.166e+03 2.254e+03
# %SIGMA@wn2*.pc3%            2.984e+02 3.111e+02 3.180e+02 3.251e+02 3.392e+02
# %SIGMA@wn2*.pc5%            2.454e+01 2.558e+01 2.614e+01 2.672e+01 2.780e+01
# a5_infiltration_rate        8.453e-03 7.462e-02 1.483e-01 2.473e-01 5.776e-01
# %SIGMA@wn2*.pc6%            1.278e+01 1.333e+01 1.363e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.321e+01 1.349e+01 1.380e+01 1.436e+01
#
# *** Simulation 155 / <until converged> (elapsed time: 1.13 mins) ***
#
# Iterations = 1550:57346
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 13950
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.253e-01    0.1069 9.048e-04       0.001522
# e1_natural_ventilation_rate 7.281e-01    0.1034 8.755e-04       0.002123
# %SIGMA@wn2*.pc.mu%          1.481e+05 4789.8901 4.055e+01      47.831127
# b10_airloophvac             7.570e-01    0.2022 1.712e-03       0.004630
# %SIGMA@wn2*.pc1%            1.121e+05 3625.3718 3.069e+01      36.293982
# %SIGMA@wn2*.pc2%            2.120e+03   68.0518 5.762e-01       0.679383
# %SIGMA@wn2*.pc3%            3.183e+02   10.3318 8.748e-02       0.104924
# %SIGMA@wn2*.pc5%            2.615e+01    0.8402 7.114e-03       0.008431
# a5_infiltration_rate        1.826e-01    0.1495 1.266e-03       0.001895
# %SIGMA@wn2*.pc6%            1.363e+01    0.4424 3.745e-03       0.004433
# %SIGMA@wn2*.pc7%            1.350e+01    0.4367 3.697e-03       0.004402
#                                     t    eff     s
# d2_htgsp_office_st          0.0046780 0.3535  4931
# e1_natural_ventilation_rate 0.0029166 0.1700  2372
# %SIGMA@wn2*.pc.mu%          0.0003230 0.7189 10028
# b10_airloophvac             0.0061161 0.1368  1908
# %SIGMA@wn2*.pc1%            0.0003238 0.7153  9978
# %SIGMA@wn2*.pc2%            0.0003205 0.7192 10033
# %SIGMA@wn2*.pc3%            0.0003297 0.6951  9696
# %SIGMA@wn2*.pc5%            0.0003224 0.7119  9932
# a5_infiltration_rate        0.0103791 0.4462  6224
# %SIGMA@wn2*.pc6%            0.0003251 0.7140  9960
# %SIGMA@wn2*.pc7%            0.0003259 0.7055  9842
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.184e-02 2.609e-01 3.319e-01 3.988e-01 5.177e-01
# e1_natural_ventilation_rate 5.368e-01 6.570e-01 7.233e-01 7.921e-01 9.565e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.480e+05 1.513e+05 1.576e+05
# b10_airloophvac             3.116e-01 6.277e-01 7.948e-01 9.377e-01 9.961e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.121e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.073e+03 2.119e+03 2.166e+03 2.254e+03
# %SIGMA@wn2*.pc3%            2.984e+02 3.111e+02 3.180e+02 3.250e+02 3.392e+02
# %SIGMA@wn2*.pc5%            2.454e+01 2.558e+01 2.614e+01 2.671e+01 2.781e+01
# a5_infiltration_rate        8.676e-03 7.490e-02 1.483e-01 2.468e-01 5.747e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.363e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.321e+01 1.350e+01 1.380e+01 1.436e+01
#
# *** Simulation 160 / <until converged> (elapsed time: 1.17 mins) ***
#
# Iterations = 1600:59196
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 14400
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.258e-01    0.1069 8.911e-04       0.001511
# e1_natural_ventilation_rate 7.270e-01    0.1036 8.629e-04       0.002129
# %SIGMA@wn2*.pc.mu%          1.481e+05 4785.5244 3.988e+01      47.159806
# b10_airloophvac             7.543e-01    0.2035 1.696e-03       0.004660
# %SIGMA@wn2*.pc1%            1.121e+05 3619.5554 3.016e+01      35.578080
# %SIGMA@wn2*.pc2%            2.120e+03   68.0667 5.672e-01       0.666852
# %SIGMA@wn2*.pc3%            3.183e+02   10.3408 8.617e-02       0.103096
# %SIGMA@wn2*.pc5%            2.615e+01    0.8401 7.001e-03       0.008288
# a5_infiltration_rate        1.818e-01    0.1492 1.243e-03       0.001857
# %SIGMA@wn2*.pc6%            1.363e+01    0.4434 3.695e-03       0.004324
# %SIGMA@wn2*.pc7%            1.350e+01    0.4363 3.636e-03       0.004337
#                                     t    eff     s
# d2_htgsp_office_st          0.0046370 0.3478  5009
# e1_natural_ventilation_rate 0.0029282 0.1643  2366
# %SIGMA@wn2*.pc.mu%          0.0003184 0.7151 10297
# b10_airloophvac             0.0061785 0.1324  1907
# %SIGMA@wn2*.pc1%            0.0003175 0.7188 10350
# %SIGMA@wn2*.pc2%            0.0003146 0.7235 10419
# %SIGMA@wn2*.pc3%            0.0003239 0.6987 10061
# %SIGMA@wn2*.pc5%            0.0003169 0.7136 10276
# a5_infiltration_rate        0.0102133 0.4481  6452
# %SIGMA@wn2*.pc6%            0.0003171 0.7304 10518
# %SIGMA@wn2*.pc7%            0.0003212 0.7027 10119
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.214e-02 2.620e-01 3.324e-01 3.993e-01 5.185e-01
# e1_natural_ventilation_rate 5.350e-01 6.559e-01 7.224e-01 7.909e-01 9.548e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.481e+05 1.513e+05 1.575e+05
# b10_airloophvac             3.081e-01 6.235e-01 7.912e-01 9.362e-01 9.961e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.073e+03 2.119e+03 2.166e+03 2.254e+03
# %SIGMA@wn2*.pc3%            2.984e+02 3.112e+02 3.181e+02 3.251e+02 3.392e+02
# %SIGMA@wn2*.pc5%            2.455e+01 2.558e+01 2.614e+01 2.672e+01 2.781e+01
# a5_infiltration_rate        8.503e-03 7.465e-02 1.473e-01 2.460e-01 5.744e-01
# %SIGMA@wn2*.pc6%            1.277e+01 1.333e+01 1.363e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.321e+01 1.350e+01 1.380e+01 1.436e+01
#
# *** Simulation 165 / <until converged> (elapsed time: 1.21 mins) ***
#
# Iterations = 1650:61046
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 14850
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.259e-01    0.1070 8.778e-04       0.001485
# e1_natural_ventilation_rate 7.274e-01    0.1037 8.506e-04       0.002100
# %SIGMA@wn2*.pc.mu%          1.481e+05 4781.4275 3.924e+01      46.413371
# b10_airloophvac             7.549e-01    0.2032 1.667e-03       0.004595
# %SIGMA@wn2*.pc1%            1.121e+05 3619.5776 2.970e+01      35.043397
# %SIGMA@wn2*.pc2%            2.120e+03   68.0235 5.582e-01       0.656527
# %SIGMA@wn2*.pc3%            3.183e+02   10.3400 8.485e-02       0.101574
# %SIGMA@wn2*.pc5%            2.615e+01    0.8410 6.901e-03       0.008372
# a5_infiltration_rate        1.818e-01    0.1492 1.224e-03       0.001829
# %SIGMA@wn2*.pc6%            1.363e+01    0.4427 3.633e-03       0.004248
# %SIGMA@wn2*.pc7%            1.350e+01    0.4362 3.579e-03       0.004268
#                                     t    eff     s
# d2_htgsp_office_st          0.0045567 0.3493  5188
# e1_natural_ventilation_rate 0.0028870 0.1640  2436
# %SIGMA@wn2*.pc.mu%          0.0003134 0.7147 10613
# b10_airloophvac             0.0060867 0.1316  1955
# %SIGMA@wn2*.pc1%            0.0003127 0.7184 10669
# %SIGMA@wn2*.pc2%            0.0003097 0.7229 10735
# %SIGMA@wn2*.pc3%            0.0003192 0.6978 10363
# %SIGMA@wn2*.pc5%            0.0003201 0.6796 10092
# a5_infiltration_rate        0.0100588 0.4481  6654
# %SIGMA@wn2*.pc6%            0.0003116 0.7314 10861
# %SIGMA@wn2*.pc7%            0.0003161 0.7033 10444
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.155e-02 2.620e-01 3.326e-01 3.996e-01 5.180e-01
# e1_natural_ventilation_rate 5.358e-01 6.564e-01 7.228e-01 7.916e-01 9.565e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.480e+05 1.513e+05 1.575e+05
# b10_airloophvac             3.098e-01 6.247e-01 7.916e-01 9.366e-01 9.962e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.192e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.073e+03 2.119e+03 2.166e+03 2.253e+03
# %SIGMA@wn2*.pc3%            2.984e+02 3.111e+02 3.180e+02 3.251e+02 3.392e+02
# %SIGMA@wn2*.pc5%            2.455e+01 2.558e+01 2.615e+01 2.672e+01 2.782e+01
# a5_infiltration_rate        8.543e-03 7.462e-02 1.472e-01 2.461e-01 5.746e-01
# %SIGMA@wn2*.pc6%            1.278e+01 1.333e+01 1.363e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.321e+01 1.350e+01 1.380e+01 1.436e+01
#
# *** Simulation 170 / <until converged> (elapsed time: 1.24 mins) ***
#
# Iterations = 1700:62896
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 15300
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.259e-01    0.1070 8.653e-04       0.001467
# e1_natural_ventilation_rate 7.268e-01    0.1036 8.378e-04       0.002070
# %SIGMA@wn2*.pc.mu%          1.481e+05 4789.8414 3.872e+01      45.862901
# b10_airloophvac             7.539e-01    0.2039 1.649e-03       0.004537
# %SIGMA@wn2*.pc1%            1.121e+05 3614.0927 2.922e+01      34.103249
# %SIGMA@wn2*.pc2%            2.120e+03   68.0290 5.500e-01       0.647673
# %SIGMA@wn2*.pc3%            3.183e+02   10.3663 8.381e-02       0.100632
# %SIGMA@wn2*.pc5%            2.615e+01    0.8414 6.802e-03       0.008243
# a5_infiltration_rate        1.815e-01    0.1489 1.204e-03       0.001796
# %SIGMA@wn2*.pc6%            1.363e+01    0.4430 3.582e-03       0.004234
# %SIGMA@wn2*.pc7%            1.350e+01    0.4365 3.529e-03       0.004217
#                                     t    eff     s
# d2_htgsp_office_st          0.0045014 0.3479  5323
# e1_natural_ventilation_rate 0.0028482 0.1638  2506
# %SIGMA@wn2*.pc.mu%          0.0003097 0.7129 10907
# b10_airloophvac             0.0060179 0.1321  2021
# %SIGMA@wn2*.pc1%            0.0003043 0.7340 11231
# %SIGMA@wn2*.pc2%            0.0003055 0.7211 11033
# %SIGMA@wn2*.pc3%            0.0003162 0.6936 10611
# %SIGMA@wn2*.pc5%            0.0003152 0.6811 10420
# a5_infiltration_rate        0.0098942 0.4493  6874
# %SIGMA@wn2*.pc6%            0.0003105 0.7158 10951
# %SIGMA@wn2*.pc7%            0.0003122 0.7005 10717
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.201e-02 2.615e-01 3.324e-01 3.995e-01 5.186e-01
# e1_natural_ventilation_rate 5.349e-01 6.558e-01 7.224e-01 7.909e-01 9.550e-01
# %SIGMA@wn2*.pc.mu%          1.389e+05 1.449e+05 1.480e+05 1.513e+05 1.575e+05
# b10_airloophvac             3.054e-01 6.229e-01 7.909e-01 9.361e-01 9.961e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.073e+03 2.119e+03 2.166e+03 2.254e+03
# %SIGMA@wn2*.pc3%            2.983e+02 3.112e+02 3.181e+02 3.251e+02 3.392e+02
# %SIGMA@wn2*.pc5%            2.455e+01 2.558e+01 2.615e+01 2.672e+01 2.781e+01
# a5_infiltration_rate        8.535e-03 7.446e-02 1.470e-01 2.458e-01 5.746e-01
# %SIGMA@wn2*.pc6%            1.278e+01 1.333e+01 1.363e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.321e+01 1.350e+01 1.380e+01 1.436e+01
#
# $CALIBRATION_RESULTS
#                     PARAMETER   ESTIMATE      LOWER      UPPER
# 1          d2_htgsp_office_st 13.9765257 12.6105648 15.1721878
# 2 e1_natural_ventilation_rate  0.6603900  0.4789320  0.8488362
# 3             b10_airloophvac  0.9995293  0.8291717  0.9999548
# 4        a5_infiltration_rate  0.1716862  0.1610020  0.2129054
#
# $CALIBRATED_MODEL_GOF
#               sim        cals
# data1 0.006458169 0.006611452
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 7: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
#
#
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# ✓ Calibro finished successfully.
#
# 🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_2/output
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 7: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
