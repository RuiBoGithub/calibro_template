# %%
import pandas as pd
from pathlib import Path

data_dir = Path("calibro_original")
df_obs = pd.read_csv(data_dir / "obs.csv")
df_TT = pd.read_csv(data_dir / "calib_sampling-EMS-ABM-u.csv")
df_Y  = pd.read_csv(data_dir / "df_q1_q3_q4_hvac_filtered.csv")

print("=== FILE DIMENSIONS ===")
print(f"obs shape: {df_obs.shape}")
print(f"TT shape:      {df_TT.shape}")
print(f"Y shape:       {df_Y.shape}")

print("\n=== COLUMN NAMES ===")
print("obs:", list(df_obs.columns))
print("TT:",  list(df_TT.columns))
print("Y:",   list(df_Y.columns))
# Out:
# === FILE DIMENSIONS ===
# obs shape: (120, 1)
# TT shape:      (20, 6)
# Y shape:       (120, 20)
#
# === COLUMN NAMES ===
# obs: ['actual']
# TT: ['BaseLoad_Q1', 'BaseLoad_Q34', 'PplInt_Q1', 'PplInt_Q34', 'EqInt_Q1', 'EqInt_Q34']
# Y: ['sample_0_full', 'sample_1_full', 'sample_2_full', 'sample_3_full', 'sample_4_full', 'sample_5_full', 'sample_6_full', 'sample_7_full', 'sample_8_full', 'sample_9_full', 'sample_10_full', 'sample_11_full', 'sample_12_full', 'sample_13_full', 'sample_14_full', 'sample_15_full', 'sample_16_full', 'sample_17_full', 'sample_18_full', 'sample_19_full']

# %% [markdown]
# # Coding

# %%
# ---- Unique dir ----
EXP_NAME = "exp_2"

# ---- Column names ----
METERING_COLUMN    = "Main Heating"
START_DATE = "2023-03-01"
END_DATE   = "2023-04-01"
AREA_M2 = 9184

# ---- Source files ----
SRC_METERING = "../ihg_generator/Metering.csv"
SRC_TT       = "../eplus_diagnosis/output-AUTO3_csv/samples_AUTO3.csv"
SRC_Y        = "../eplus_diagnosis/output-AUTO3_csv/DistrictHeatingWater_Facility_timeseries.csv"

# ---- R environment ----
CALIBRO_NAME = "simplest"
RSCRIPT_BIN = "Rscript"

# ---- Fixed term ----
METERING_TIMESTAMP = "Timestamp"
TT_DROP_COLUMNS = ["CSV File"]

# %%
import pandas as pd
from pathlib import Path
import subprocess

# 0. Resolve experiment directories
base_dir = Path(".").resolve()
exp_dir = base_dir / EXP_NAME

data_dir  = exp_dir / "data"
code_dir  = exp_dir / "code"
output_dir = exp_dir / "output"

for d in [data_dir, code_dir, output_dir]:
    d.mkdir(parents=True, exist_ok=True)

print(f"[INFO] Experiment folder prepared at: {exp_dir}")


# 1. Extract obs.csv (March + normalised)
df_meter = pd.read_csv(SRC_METERING)
df_meter[METERING_TIMESTAMP] = pd.to_datetime(df_meter[METERING_TIMESTAMP], dayfirst=True)

df_obs = df_meter.loc[
    (df_meter[METERING_TIMESTAMP] >= START_DATE) &
    (df_meter[METERING_TIMESTAMP] <  END_DATE),
    [METERING_COLUMN]
].reset_index(drop=True)

# area normalisation
df_obs[METERING_COLUMN] = df_obs[METERING_COLUMN] / AREA_M2

df_obs.to_csv(data_dir / "obs.csv", index=False)
print("[INFO] obs.csv saved:", df_obs.shape)


# 2. Extract TT.csv
df_TT = pd.read_csv(SRC_TT)

for col in TT_DROP_COLUMNS:
    if col in df_TT.columns:
        df_TT = df_TT.drop(columns=[col])

df_TT.to_csv(data_dir / "TT.csv", index=False)
print("[INFO] TT.csv saved:", df_TT.shape)


# 3. Extract Y.csv (March)
df_Y = pd.read_csv(SRC_Y)

# auto-detect timestamp column
ts_cols = [c for c in df_Y.columns if "time" in c.lower() or "stamp" in c.lower()]
if not ts_cols:
    raise ValueError("__!__ No timestamp column found in Y file")
ts_col = ts_cols[0]

df_Y[ts_col] = pd.to_datetime(df_Y[ts_col])

df_Y_march = df_Y.loc[
    (df_Y[ts_col] >= START_DATE) &
    (df_Y[ts_col] <  END_DATE)
].reset_index(drop=True)

df_Y_final = df_Y_march.drop(columns=[ts_col])

df_Y_final.to_csv(data_dir / "Y.csv", index=False)
print("[INFO] Y.csv saved:", df_Y_final.shape)


# 4. Validate Calibro shape requirements
if df_obs.shape[0] != df_Y_final.shape[0]:
    raise ValueError("__!__ obs and Y row count mismatch!")

print("# Shape validation passed.")


# 5. Generate R script
r_script_path = code_dir / "run_calibro.R"

r_code = f"""
setwd("{output_dir}")

library(calibro)

CE <- calEnv$new(name = '{CALIBRO_NAME}')

CE$add.ds(
    name = 'data1',
    Y.star = '{data_dir}/obs.csv',
    TT     = '{data_dir}/TT.csv',
    Y      = '{data_dir}/Y.csv'
)

CE$rd = 'pca'
CE$sa = 'sobolSmthSpl'
CE$ret = list(mthd = 'ng.screening')
CE$mdls = 'gpr.ng.sePar01_whitePar01'
CE$train = list(type = 'training', alg = 'amoeba')
CE$cals = 'cal.gpr.ng'
CE$cal.mcmc = list(alg = 'amg')

CE$cal.res()

# IMPORTANT: no 'path' argument allowed
CE$genReport(
    type = 'pdf',
    out  = c('dss','cal')
)
"""

with open(r_script_path, "w") as f:
    f.write(r_code)

print("[INFO] R script generated:", r_script_path)


# 6. Run Rscript
print("\n[INFO] Running Calibro Rscript...")
cmd = [RSCRIPT_BIN, str(r_script_path)]
result = subprocess.run(cmd)

if result.returncode == 0:
    print("# Calibro finished successfully.")
else:
    print("__!__ Calibro failed.")
# Out:
# [INFO] Experiment folder prepared at: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_2
# [INFO] obs.csv saved: (744, 1)
# [INFO] TT.csv saved: (100, 6)
# [INFO] Y.csv saved: (744, 100)
# # Shape validation passed.
# [INFO] R script generated: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/exp_2/code/run_calibro.R
#
# [INFO] Running Calibro Rscript...
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 09:58:50.825962
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00252 mins) ***
#
#  best y: 709.125921460831
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.08306
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 1
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 105500000
#
# *** Simulation 2 / 5 (elapsed time: 0.0036 mins) ***
#
#  best y: 709.125921460831
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.08306
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 1
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 105500000
#
# *** Simulation 3 / 5 (elapsed time: 0.00597 mins) ***
#
#  best y: 787.211123032774
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.4362
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.004946
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 106500000
#
# *** Simulation 4 / 5 (elapsed time: 0.00844 mins) ***
#
#  best y: 794.64443926286
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.3237
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3108
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 1.06e+08
#
# *** Simulation 5 / 5 (elapsed time: 0.0106 mins) ***
#
#  best y: 794.64443926286
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.3237
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3108
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 1.06e+08
#
# *** Simulation 6 / 5 (elapsed time: 0.0127 mins) ***
#
#  best y: 795.023727603176
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc.mu = 0.5159
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.3557
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 106300000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 09:58:51.648322
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00292 mins) ***
#
#  best y: 789.162917926536
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.7866
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.733
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.6193
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 78720000
#
# *** Simulation 2 / 5 (elapsed time: 0.00589 mins) ***
#
#  best y: 791.5959651625
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.8084
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.6846
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.281
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 81240000
#
# *** Simulation 3 / 5 (elapsed time: 0.00841 mins) ***
#
#  best y: 791.5959651625
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.8084
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.6846
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.281
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 81240000
#
# *** Simulation 4 / 5 (elapsed time: 0.0125 mins) ***
#
#  best y: 791.5959651625
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.8084
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.6846
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.281
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 81240000
#
# *** Simulation 5 / 5 (elapsed time: 0.0149 mins) ***
#
#  best y: 793.836599949291
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.7792
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.6914
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.3013
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 79310000
#
# *** Simulation 6 / 5 (elapsed time: 0.0176 mins) ***
#
#  best y: 793.836599949291
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.7792
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc1 = 0.6914
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.3013
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 79310000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 09:58:52.758388
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00381 mins) ***
#
#  best y: 525.922538230658
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.8005
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7109
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.5384
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1520000
#
# *** Simulation 2 / 5 (elapsed time: 0.00724 mins) ***
#
#  best y: 525.922538230658
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.8005
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7109
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.5384
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1520000
#
# *** Simulation 3 / 5 (elapsed time: 0.00991 mins) ***
#
#  best y: 525.922538230658
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc2 = 0.8005
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc2 = 0.7109
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.5384
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 1520000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 09:58:53.408987
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00172 mins) ***
#
#  best y: 385.069749188033
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.005016
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.9997
# 	 %ALPHA1@sePar01.pc3 = 0.9995
# 	 %SIGMA1@wn1.pc3 = 0.9976
# 	 %SIGMA1@wn2.pc3 = 236200
#
# *** Simulation 2 / 5 (elapsed time: 0.0031 mins) ***
#
#  best y: 445.327078201526
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1521
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.4685
# 	 %ALPHA1@sePar01.pc3 = 0.9993
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 239900
#
# *** Simulation 3 / 5 (elapsed time: 0.00481 mins) ***
#
#  best y: 445.327078201526
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1521
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.4685
# 	 %ALPHA1@sePar01.pc3 = 0.9993
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 239900
#
# *** Simulation 4 / 5 (elapsed time: 0.00588 mins) ***
#
#  best y: 449.008976785017
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.349
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.612
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 235300
#
# *** Simulation 5 / 5 (elapsed time: 0.00782 mins) ***
#
#  best y: 449.626844934761
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.2459
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.5142
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 236500
#
# *** Simulation 6 / 5 (elapsed time: 0.00875 mins) ***
#
#  best y: 449.626844934761
#  best z:
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.2459
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc3 = 0.5142
# 	 %ALPHA1@sePar01.pc3 = 0.9994
# 	 %SIGMA1@wn1.pc3 = 0.9991
# 	 %SIGMA1@wn2.pc3 = 236500
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 09:58:53.995609
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00114 mins) ***
#
#  best y: 382.093808926429
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.06377
# 	 %ALPHA1@sePar01.pc5 = 0.9995
# 	 %SIGMA1@wn1.pc5 = 0.9976
# 	 %SIGMA1@wn2.pc5 = 18890
#
# *** Simulation 2 / 5 (elapsed time: 0.0021 mins) ***
#
#  best y: 382.766415182182
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.06857
# 	 %ALPHA1@sePar01.pc5 = 0.9995
# 	 %SIGMA1@wn1.pc5 = 0.9975
# 	 %SIGMA1@wn2.pc5 = 18820
#
# *** Simulation 3 / 5 (elapsed time: 0.00296 mins) ***
#
#  best y: 383.001876943599
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.01735
# 	 %ALPHA1@sePar01.pc5 = 0.9995
# 	 %SIGMA1@wn1.pc5 = 0.9975
# 	 %SIGMA1@wn2.pc5 = 18850
#
# *** Simulation 4 / 5 (elapsed time: 0.0039 mins) ***
#
#  best y: 383.001876943599
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.01735
# 	 %ALPHA1@sePar01.pc5 = 0.9995
# 	 %SIGMA1@wn1.pc5 = 0.9975
# 	 %SIGMA1@wn2.pc5 = 18850
#
# *** Simulation 5 / 5 (elapsed time: 0.00484 mins) ***
#
#  best y: 384.057241469602
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 0.0007382
# 	 %ALPHA1@sePar01.pc5 = 0.9994
# 	 %SIGMA1@wn1.pc5 = 0.9977
# 	 %SIGMA1@wn2.pc5 = 18750
#
# *** Simulation 6 / 5 (elapsed time: 0.00671 mins) ***
#
#  best y: 384.403741809899
#  best z:
# 	 %RHO@b10_airloophvac%@sePar01.pc5 = 2.985e-05
# 	 %ALPHA1@sePar01.pc5 = 0.9994
# 	 %SIGMA1@wn1.pc5 = 0.9977
# 	 %SIGMA1@wn2.pc5 = 18780
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 09:58:54.452602
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00146 mins) ***
#
#  best y: 370.641682344328
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 3.659e-05
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9972
# 	 %SIGMA1@wn2.pc6 = 9882
#
# *** Simulation 2 / 5 (elapsed time: 0.00294 mins) ***
#
#  best y: 373.228335322723
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.02861
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9956
#
# *** Simulation 3 / 5 (elapsed time: 0.00389 mins) ***
#
#  best y: 373.228335322723
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.02861
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9956
#
# *** Simulation 4 / 5 (elapsed time: 0.00525 mins) ***
#
#  best y: 373.357437400385
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.02652
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9931
#
# *** Simulation 5 / 5 (elapsed time: 0.00609 mins) ***
#
#  best y: 373.357437400385
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.02652
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9931
#
# *** Simulation 6 / 5 (elapsed time: 0.00684 mins) ***
#
#  best y: 373.363228181325
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc6 = 0.02856
# 	 %ALPHA1@sePar01.pc6 = 0.9995
# 	 %SIGMA1@wn1.pc6 = 0.9973
# 	 %SIGMA1@wn2.pc6 = 9933
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-13 09:58:54.915684
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00144 mins) ***
#
#  best y: 345.742825892556
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.07501
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.996
# 	 %SIGMA1@wn2.pc7 = 9681
#
# *** Simulation 2 / 5 (elapsed time: 0.00254 mins) ***
#
#  best y: 345.742825892556
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.07501
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.996
# 	 %SIGMA1@wn2.pc7 = 9681
#
# *** Simulation 3 / 5 (elapsed time: 0.00339 mins) ***
#
#  best y: 345.742825892556
#  best z:
# 	 %RHO@a5_infiltration_rate%@sePar01.pc7 = 0.07501
# 	 %ALPHA1@sePar01.pc7 = 0.9997
# 	 %SIGMA1@wn1.pc7 = 0.996
# 	 %SIGMA1@wn2.pc7 = 9681
#
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2025-11-13 09:58:56.446563
#  Number of chains: 1
#  Number of simulations: <until converged>
#
# *** Simulation 5 / <until converged> (elapsed time: 0.0493 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.340e-01    0.1023 4.822e-03      8.028e-03
# e1_natural_ventilation_rate 7.432e-01    0.1011 4.767e-03      1.172e-02
# %SIGMA@wn2*.pc.mu%          1.475e+05 4554.9110 2.147e+02      4.728e+02
# b10_airloophvac             7.686e-01    0.1881 8.866e-03      2.461e-02
# %SIGMA@wn2*.pc1%            1.119e+05 3503.3768 1.652e+02      2.505e+02
# %SIGMA@wn2*.pc2%            2.125e+03   64.1872 3.026e+00      4.360e+00
# %SIGMA@wn2*.pc3%            3.169e+02   10.9146 5.145e-01      7.753e-01
# %SIGMA@wn2*.pc5%            2.622e+01    0.8388 3.954e-02      5.947e-02
# a5_infiltration_rate        1.810e-01    0.1569 7.395e-03      1.302e-02
# %SIGMA@wn2*.pc6%            1.361e+01    0.4557 2.148e-02      3.184e-02
# %SIGMA@wn2*.pc7%            1.355e+01    0.4357 2.054e-02      3.140e-02
#                                    t    eff      s
# d2_htgsp_office_st          0.024034 0.3608 162.36
# e1_natural_ventilation_rate 0.015770 0.1654  74.45
# %SIGMA@wn2*.pc.mu%          0.003206 0.2062  92.81
# b10_airloophvac             0.032012 0.1298  58.43
# %SIGMA@wn2*.pc1%            0.002237 0.4348 195.67
# %SIGMA@wn2*.pc2%            0.002051 0.4817 216.75
# %SIGMA@wn2*.pc3%            0.002447 0.4405 198.21
# %SIGMA@wn2*.pc5%            0.002268 0.4421 198.96
# a5_infiltration_rate        0.071933 0.3227 145.23
# %SIGMA@wn2*.pc6%            0.002340 0.4552 204.85
# %SIGMA@wn2*.pc7%            0.002317 0.4277 192.48
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          1.179e-01 2.739e-01 3.391e-01 3.988e-01 5.156e-01
# e1_natural_ventilation_rate 5.685e-01 6.727e-01 7.356e-01 8.059e-01 9.754e-01
# %SIGMA@wn2*.pc.mu%          1.388e+05 1.445e+05 1.474e+05 1.506e+05 1.567e+05
# b10_airloophvac             3.411e-01 6.495e-01 8.048e-01 9.305e-01 9.912e-01
# %SIGMA@wn2*.pc5%            2.615e+01    0.8278 1.745e-02      1.996e-02
# a5_infiltration_rate        1.797e-01    0.1518 3.200e-03      4.810e-03
# %SIGMA@wn2*.pc6%            1.362e+01    0.4363 9.199e-03      1.101e-02
# %SIGMA@wn2*.pc7%            1.352e+01    0.4441 9.362e-03      1.109e-02
#                                     t    eff      s
# d2_htgsp_office_st          0.0107171 0.4102  922.9
# e1_natural_ventilation_rate 0.0074036 0.1556  350.0
# %SIGMA@wn2*.pc.mu%          0.0008709 0.6516 1466.1
# b10_airloophvac             0.0150152 0.1221  274.6
# %SIGMA@wn2*.pc1%            0.0008496 0.6468 1455.3
# %SIGMA@wn2*.pc2%            0.0008146 0.6709 1509.5
# %SIGMA@wn2*.pc3%            0.0008057 0.7310 1644.7
# %SIGMA@wn2*.pc5%            0.0007633 0.7644 1719.8
# a5_infiltration_rate        0.0267623 0.4425  995.6
# %SIGMA@wn2*.pc6%            0.0008086 0.6975 1569.3
# %SIGMA@wn2*.pc7%            0.0008202 0.7131 1604.5
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.360e-02 2.595e-01 3.346e-01 3.975e-01 5.081e-01
# e1_natural_ventilation_rate 5.469e-01 6.736e-01 7.384e-01 8.085e-01 9.591e-01
# %SIGMA@wn2*.pc.mu%          1.386e+05 1.446e+05 1.480e+05 1.513e+05 1.578e+05
# b10_airloophvac             3.279e-01 6.519e-01 8.280e-01 9.441e-01 9.948e-01
# %SIGMA@wn2*.pc1%            1.053e+05 1.095e+05 1.121e+05 1.145e+05 1.194e+05
# %SIGMA@wn2*.pc2%            1.990e+03 2.073e+03 2.119e+03 2.165e+03 2.253e+03
# %SIGMA@wn2*.pc3%            2.986e+02 3.109e+02 3.180e+02 3.253e+02 3.388e+02
# %SIGMA@wn2*.pc5%            2.452e+01 2.561e+01 2.615e+01 2.669e+01 2.781e+01
# a5_infiltration_rate        8.037e-03 6.962e-02 1.423e-01 2.429e-01 5.736e-01
# %SIGMA@wn2*.pc6%            1.279e+01 1.331e+01 1.363e+01 1.393e+01 1.448e+01
# %SIGMA@wn2*.pc7%            1.267e+01 1.321e+01 1.351e+01 1.381e+01 1.440e+01
#
# *** Simulation 30 / <until converged> (elapsed time: 0.226 mins) ***
#
# Iterations = 300:11096
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 2700
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.265e-01    0.1059  0.002039      3.118e-03
# e1_natural_ventilation_rate 7.401e-01    0.1026  0.001974      5.090e-03
# %SIGMA@wn2*.pc.mu%          1.480e+05 4864.9061 93.625162      1.127e+02
# b10_airloophvac             7.752e-01    0.1952  0.003756      1.258e-02
# %SIGMA@wn2*.pc1%            1.121e+05 3614.5849 69.562720      8.137e+01
# %SIGMA@wn2*.pc2%            2.119e+03   68.6012  1.320230      1.558e+00
# %SIGMA@wn2*.pc3%            3.182e+02   10.4346  0.200815      2.398e-01
# %SIGMA@wn2*.pc5%            2.615e+01    0.8264  0.015904      1.895e-02
# a5_infiltration_rate        1.801e-01    0.1500  0.002887      4.361e-03
# %SIGMA@wn2*.pc6%            1.362e+01    0.4336  0.008344      9.978e-03
# %SIGMA@wn2*.pc7%            1.351e+01    0.4451  0.008566      1.015e-02
#                                     t     eff      s
# d2_htgsp_office_st          0.0095492 0.42755 1154.4
mins) ***
#
# Iterations = 550:20346
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 4950
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.248e-01    0.1072  0.001523       0.002521
# e1_natural_ventilation_rate 7.377e-01    0.1019  0.001448       0.003539
# %SIGMA@wn2*.pc.mu%          1.481e+05 4872.0562 69.248391      82.890322
# b10_airloophvac             7.718e-01    0.1952  0.002775       0.007803
# %SIGMA@wn2*.pc1%            1.121e+05 3582.8884 50.924958      58.959400
# %SIGMA@wn2*.pc2%            2.119e+03   68.4405  0.972771       1.198133
# %SIGMA@wn2*.pc3%            3.185e+02   10.4821  0.148986       0.177221
# %SIGMA@wn2*.pc5%            2.616e+01    0.8298  0.011795       0.014106
# a5_infiltration_rate        1.759e-01    0.1469  0.002088       0.003077
# %SIGMA@wn2*.pc6%            1.363e+01    0.4331  0.006156       0.007342
# %SIGMA@wn2*.pc7%            1.350e+01    0.4414  0.006274       0.007453
#                                     t    eff    s
# d2_htgsp_office_st          0.0077609 0.3652 1808
# e1_natural_ventilation_rate 0.0047979 0.1673  828
# %SIGMA@wn2*.pc.mu%          0.0005596 0.6979 3455
# b10_airloophvac             0.0101099 0.1265  626
# %SIGMA@wn2*.pc1%            0.0005258 0.7460 3693
# %SIGMA@wn2*.pc2%            0.0005655 0.6592 3263
# %SIGMA@wn2*.pc3%            0.0005564 0.7067 3498
# %SIGMA@wn2*.pc5%            0.0005393 0.6992 3461
# a5_infiltration_rate        0.0174913 0.4608 2281
# %SIGMA@wn2*.pc6%            0.0005387 0.7030 3480
# %SIGMA@wn2*.pc7%            0.0005520 0.7087 3508
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.149e-02 2.594e-01 3.347e-01 3.987e-01 5.132e-01
# e1_natural_ventilation_rate 5.405e-01 6.683e-01 7.357e-01 8.043e-01 9.540e-01
# %SIGMA@wn2*.pc.mu%          1.387e+05 1.448e+05 1.482e+05 1.514e+05 1.578e+05
# b10_airloophvac             3.329e-01 6.440e-01 8.148e-01 9.419e-01 9.960e-01
# %SIGMA@wn2*.pc1%            1.053e+05 1.097e+05 1.122e+05 1.145e+05 1.194e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.072e+03 2.118e+03 2.164e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.988e+02 3.111e+02 3.184e+02 3.257e+02 3.390e+02
# %SIGMA@wn2*.pc5%            2.454e+01 2.561e+01 2.615e+01 2.670e+01 2.781e+01
# a5_infiltration_rate        7.724e-03 6.790e-02 1.421e-01 2.401e-01 5.592e-01
# %SIGMA@wn2*.pc6%            1.280e+01 1.333e+01 1.364e+01 1.392e+01 1.450e+01
# %SIGMA@wn2*.pc7%            1.265e+01 1.319e+01 1.350e+01 1.380e+01 1.438e+01
#
# *** Simulation 60 / <until converged> (elapsed time: 0.44 mins) ***
#
# Iterations = 600:22196
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 5400
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.244e-01    0.1067  0.001452       0.002379
# e1_natural_ventilation_rate 7.381e-01    0.1026  0.001396       0.003405
# %SIGMA@wn2*.pc.mu%          1.481e+05 4873.0936 66.314404      78.941149
# b10_airloophvac             7.727e-01    0.1958  0.002664       0.007463
# %SIGMA@wn2*.pc1%            1.121e+05 3573.5266 48.629537      56.119233
# %SIGMA@wn2*.pc2%            2.119e+03   68.4886  0.932011       1.122083
# %SIGMA@wn2*.pc3%            3.185e+02   10.4610  0.142356       0.170162
# %SIGMA@wn2*.pc5%            2.615e+01    0.8265  0.011247       0.013469
# a5_infiltration_rate        1.772e-01    0.1489  0.002027       0.003000
# %SIGMA@wn2*.pc6%            1.363e+01    0.4301  0.005853       0.007024
# %SIGMA@wn2*.pc7%            1.350e+01    0.4407  0.005997       0.007477
#                                     t    eff      s
# d2_htgsp_office_st          0.0073336 0.3725 2011.7
# e1_natural_ventilation_rate 0.0046133 0.1681  907.5
# %SIGMA@wn2*.pc.mu%          0.0005329 0.7057 3810.7
# b10_airloophvac             0.0096573 0.1275  688.3
# %SIGMA@wn2*.pc1%            0.0005005 0.7509 4054.8
# %SIGMA@wn2*.pc2%            0.0005295 0.6899 3725.5
# %SIGMA@wn2*.pc3%            0.0005343 0.6999 3779.4
# %SIGMA@wn2*.pc5%            0.0005150 0.6973 3765.3
# a5_infiltration_rate        0.0169272 0.4564 2464.4
# %SIGMA@wn2*.pc6%            0.0005152 0.6944 3749.9
# %SIGMA@wn2*.pc7%            0.0005539 0.6433 3473.7
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.354e-02 2.595e-01 3.331e-01 3.979e-01 5.126e-01
# e1_natural_ventilation_rate 5.405e-01 6.673e-01 7.364e-01 8.058e-01 9.544e-01
# %SIGMA@wn2*.pc.mu%          1.387e+05 1.448e+05 1.482e+05 1.514e+05 1.578e+05
# b10_airloophvac             3.306e-01 6.446e-01 8.178e-01 9.431e-01 9.960e-01
# %SIGMA@wn2*.pc1%            1.053e+05 1.097e+05 1.122e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.072e+03 2.119e+03 2.165e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.988e+02 3.111e+02 3.184e+02 3.257e+02 3.389e+02
# %SIGMA@wn2*.pc5%            2.454e+01 2.561e+01 2.615e+01 2.670e+01 2.780e+01
# a5_infiltration_rate        7.646e-03 6.833e-02 1.420e-01 2.418e-01 5.681e-01
# %SIGMA@wn2*.pc6%            1.280e+01 1.333e+01 1.364e+01 1.392e+01 1.450e+01
# %SIGMA@wn2*.pc7%            1.265e+01 1.319e+01 1.350e+01 1.380e+01 1.438e+01
#
# *** Simulation 65 / <until converged> (elapsed time: 0.475 mins) ***
#
# Iterations = 650:24046
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 5850
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.240e-01    0.1069  0.001397       0.002298
# e1_natural_ventilation_rate 7.396e-01    0.1022  0.001337       0.003255
# %SIGMA@wn2*.pc.mu%          1.481e+05 4874.3304 63.728989      75.959057
# b10_airloophvac             7.766e-01    0.1946  0.002544       0.007092
# %SIGMA@wn2*.pc1%            1.121e+05 3583.3830 46.850615      54.017100
# %SIGMA@wn2*.pc2%            2.119e+03   68.4351  0.894748       1.071276
# %SIGMA@wn2*.pc3%            3.185e+02   10.4257  0.136309       0.162316
# %SIGMA@wn2*.pc5%            2.616e+01    0.8307  0.010860       0.013046
# a5_infiltration_rate        1.780e-01    0.1495  0.001954       0.002894
# %SIGMA@wn2*.pc6%            1.363e+01    0.4284  0.005601       0.006703
# %SIGMA@wn2*.pc7%            1.350e+01    0.4396  0.005747       0.006896
#                                     t    eff      s
# d2_htgsp_office_st          0.0070936 0.3696 2162.2
# e1_natural_ventilation_rate 0.0044015 0.1686  986.6
# %SIGMA@wn2*.pc.mu%          0.0005128 0.7039 4117.9
# b10_airloophvac             0.0091330 0.1287  752.9
# %SIGMA@wn2*.pc1%            0.0004817 0.7523 4400.7
# %SIGMA@wn2*.pc2%            0.0005056 0.6976 4080.9
# %SIGMA@wn2*.pc3%            0.0005096 0.7052 4125.6
# %SIGMA@wn2*.pc5%            0.0004988 0.6930 4053.9
# a5_infiltration_rate        0.0162635 0.4560 2667.5
# %SIGMA@wn2*.pc6%            0.0004917 0.6982 4084.5
# %SIGMA@wn2*.pc7%            0.0005107 0.6946 4063.5
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.216e-02 2.589e-01 3.318e-01 3.980e-01 5.106e-01
# e1_natural_ventilation_rate 5.410e-01 6.699e-01 7.386e-01 8.078e-01 9.545e-01
# %SIGMA@wn2*.pc.mu%          1.387e+05 1.448e+05 1.481e+05 1.514e+05 1.577e+05
# b10_airloophvac             3.314e-01 6.502e-01 8.236e-01 9.450e-01 9.962e-01
# %SIGMA@wn2*.pc1%            1.053e+05 1.097e+05 1.121e+05 1.145e+05 1.194e+05
# %SIGMA@wn2*.pc2%            1.988e+03 2.073e+03 2.119e+03 2.165e+03 2.257e+03
# %SIGMA@wn2*.pc3%            2.988e+02 3.112e+02 3.184e+02 3.257e+02 3.388e+02
# %SIGMA@wn2*.pc5%            2.453e+01 2.561e+01 2.615e+01 2.670e+01 2.781e+01
# a5_infiltration_rate        7.703e-03 6.919e-02 1.422e-01 2.428e-01 5.710e-01
# %SIGMA@wn2*.pc6%            1.281e+01 1.333e+01 1.364e+01 1.392e+01 1.449e+01
# %SIGMA@wn2*.pc7%            1.266e+01 1.320e+01 1.350e+01 1.380e+01 1.437e+01
#
# *** Simulation 70 / <until converged> (elapsed time: 0.511 mins) ***
#
# Iterations = 700:25896
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 6300
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.236e-01    0.1063  0.001339       0.002204
# e1_natural_ventilation_rate 7.383e-01    0.1027  0.001294       0.003232
# %SIGMA@wn2*.pc.mu%          1.481e+05 4850.8807 61.115352      73.180305
# b10_airloophvac             7.751e-01    0.1957  0.002465       0.006991
# %SIGMA@wn2*.pc1%            1.121e+05 3597.6474 45.326097      52.317868
# %SIGMA@wn2*.pc2%            2.119e+03   68.4804  0.862772       1.035291
# %SIGMA@wn2*.pc3%            3.186e+02   10.4234  0.131323       0.154712
# %SIGMA@wn2*.pc5%            2.616e+01    0.8306  0.010465       0.013770
# a5_infiltration_rate        1.777e-01    0.1489  0.001876       0.002765
# ...
# %SIGMA@wn2*.pc6%            1.281e+01 1.335e+01 1.364e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.267e+01 1.320e+01 1.350e+01 1.380e+01 1.438e+01
#
# *** Simulation 155 / <until converged> (elapsed time: 1.12 mins) ***
#
# Iterations = 1550:57346
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 13950
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.226e-01    0.1045 8.848e-04       0.001492
# e1_natural_ventilation_rate 7.373e-01    0.1049 8.882e-04       0.002281
# %SIGMA@wn2*.pc.mu%          1.481e+05 4801.8934 4.066e+01      48.243270
# b10_airloophvac             7.730e-01    0.1984 1.680e-03       0.004782
# %SIGMA@wn2*.pc1%            1.121e+05 3612.1731 3.058e+01      35.963198
# %SIGMA@wn2*.pc2%            2.121e+03   68.1496 5.770e-01       0.685927
# %SIGMA@wn2*.pc3%            3.186e+02   10.4045 8.809e-02       0.103587
# %SIGMA@wn2*.pc5%            2.615e+01    0.8464 7.166e-03       0.008454
# a5_infiltration_rate        1.789e-01    0.1487 1.259e-03       0.001866
# %SIGMA@wn2*.pc6%            1.364e+01    0.4344 3.678e-03       0.004534
# %SIGMA@wn2*.pc7%            1.350e+01    0.4378 3.707e-03       0.004418
#                                     t    eff     s
# d2_htgsp_office_st          0.0046265 0.3515  4904
# e1_natural_ventilation_rate 0.0030934 0.1516  2115
# %SIGMA@wn2*.pc.mu%          0.0003258 0.7102  9907
# b10_airloophvac             0.0061864 0.1234  1721
# %SIGMA@wn2*.pc1%            0.0003209 0.7232 10088
# %SIGMA@wn2*.pc2%            0.0003234 0.7076  9871
# %SIGMA@wn2*.pc3%            0.0003252 0.7232 10089
# %SIGMA@wn2*.pc5%            0.0003232 0.7186 10025
# a5_infiltration_rate        0.0104325 0.4552  6350
# %SIGMA@wn2*.pc6%            0.0003324 0.6580  9179
# %SIGMA@wn2*.pc7%            0.0003272 0.7040  9820
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.614e-02 2.573e-01 3.289e-01 3.945e-01 5.099e-01
# e1_natural_ventilation_rate 5.390e-01 6.643e-01 7.345e-01 8.065e-01 9.593e-01
# %SIGMA@wn2*.pc.mu%          1.387e+05 1.448e+05 1.481e+05 1.513e+05 1.576e+05
# b10_airloophvac             3.273e-01 6.440e-01 8.189e-01 9.464e-01 9.965e-01
# %SIGMA@wn2*.pc1%            1.051e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.990e+03 2.075e+03 2.120e+03 2.167e+03 2.259e+03
# %SIGMA@wn2*.pc3%            2.987e+02 3.113e+02 3.184e+02 3.257e+02 3.389e+02
# %SIGMA@wn2*.pc5%            2.452e+01 2.558e+01 2.614e+01 2.672e+01 2.783e+01
# a5_infiltration_rate        7.945e-03 7.173e-02 1.435e-01 2.413e-01 5.676e-01
# %SIGMA@wn2*.pc6%            1.281e+01 1.335e+01 1.364e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.268e+01 1.320e+01 1.350e+01 1.380e+01 1.437e+01
#
# *** Simulation 160 / <until converged> (elapsed time: 1.16 mins) ***
#
# Iterations = 1600:59196
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 14400
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.223e-01    0.1047 8.728e-04       0.001471
# e1_natural_ventilation_rate 7.377e-01    0.1048 8.737e-04       0.002238
# %SIGMA@wn2*.pc.mu%          1.481e+05 4813.8743 4.012e+01      48.301829
# b10_airloophvac             7.736e-01    0.1987 1.656e-03       0.004720
# %SIGMA@wn2*.pc1%            1.121e+05 3606.9607 3.006e+01      34.505543
# %SIGMA@wn2*.pc2%            2.121e+03   68.1974 5.683e-01       0.676772
# %SIGMA@wn2*.pc3%            3.186e+02   10.4215 8.685e-02       0.102066
# %SIGMA@wn2*.pc5%            2.615e+01    0.8459 7.049e-03       0.008312
# a5_infiltration_rate        1.789e-01    0.1486 1.238e-03       0.001832
# %SIGMA@wn2*.pc6%            1.364e+01    0.4354 3.628e-03       0.004360
# %SIGMA@wn2*.pc7%            1.350e+01    0.4377 3.647e-03       0.004338
#                                     t    eff     s
# d2_htgsp_office_st          0.0045648 0.3520  5068
# e1_natural_ventilation_rate 0.0030337 0.1524  2195
# %SIGMA@wn2*.pc.mu%          0.0003262 0.6898  9933
# b10_airloophvac             0.0061010 0.1231  1773
# %SIGMA@wn2*.pc1%            0.0003079 0.7588 10927
# %SIGMA@wn2*.pc2%            0.0003191 0.7052 10154
# %SIGMA@wn2*.pc3%            0.0003204 0.7240 10425
# %SIGMA@wn2*.pc5%            0.0003178 0.7192 10357
# a5_infiltration_rate        0.0102364 0.4570  6580
# %SIGMA@wn2*.pc6%            0.0003196 0.6925  9972
# %SIGMA@wn2*.pc7%            0.0003212 0.7069 10179
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.604e-02 2.567e-01 3.285e-01 3.944e-01 5.099e-01
# e1_natural_ventilation_rate 5.387e-01 6.649e-01 7.351e-01 8.067e-01 9.591e-01
# %SIGMA@wn2*.pc.mu%          1.387e+05 1.448e+05 1.481e+05 1.513e+05 1.576e+05
# b10_airloophvac             3.249e-01 6.457e-01 8.199e-01 9.471e-01 9.966e-01
# %SIGMA@wn2*.pc1%            1.051e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.990e+03 2.075e+03 2.120e+03 2.167e+03 2.259e+03
# %SIGMA@wn2*.pc3%            2.987e+02 3.113e+02 3.184e+02 3.257e+02 3.389e+02
# %SIGMA@wn2*.pc5%            2.452e+01 2.558e+01 2.614e+01 2.672e+01 2.784e+01
# a5_infiltration_rate        8.014e-03 7.151e-02 1.437e-01 2.417e-01 5.656e-01
# %SIGMA@wn2*.pc6%            1.280e+01 1.335e+01 1.364e+01 1.393e+01 1.452e+01
# %SIGMA@wn2*.pc7%            1.268e+01 1.321e+01 1.350e+01 1.380e+01 1.437e+01
#
# *** Simulation 165 / <until converged> (elapsed time: 1.2 mins) ***
#
# Iterations = 1650:61046
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 14850
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.228e-01    0.1046 8.583e-04       0.001407
# e1_natural_ventilation_rate 7.381e-01    0.1046 8.587e-04       0.002190
# %SIGMA@wn2*.pc.mu%          1.481e+05 4815.5125 3.952e+01      47.445815
# b10_airloophvac             7.737e-01    0.1985 1.629e-03       0.004631
# %SIGMA@wn2*.pc1%            1.121e+05 3612.4915 2.964e+01      34.286511
# %SIGMA@wn2*.pc2%            2.121e+03   67.9826 5.579e-01       0.665025
# %SIGMA@wn2*.pc3%            3.186e+02   10.4313 8.560e-02       0.100676
# %SIGMA@wn2*.pc5%            2.615e+01    0.8451 6.935e-03       0.008187
# a5_infiltration_rate        1.789e-01    0.1481 1.215e-03       0.001796
# %SIGMA@wn2*.pc6%            1.364e+01    0.4345 3.565e-03       0.004268
# %SIGMA@wn2*.pc7%            1.351e+01    0.4381 3.595e-03       0.004276
#                                     t    eff     s
# d2_htgsp_office_st          0.0043580 0.3723  5529
# e1_natural_ventilation_rate 0.0029669 0.1538  2284
# %SIGMA@wn2*.pc.mu%          0.0003204 0.6937 10301
# b10_airloophvac             0.0059859 0.1238  1838
# %SIGMA@wn2*.pc1%            0.0003060 0.7476 11101
# %SIGMA@wn2*.pc2%            0.0003136 0.7037 10450
# %SIGMA@wn2*.pc3%            0.0003160 0.7229 10736
# %SIGMA@wn2*.pc5%            0.0003130 0.7175 10655
# a5_infiltration_rate        0.0100413 0.4579  6800
# %SIGMA@wn2*.pc6%            0.0003128 0.6979 10364
# %SIGMA@wn2*.pc7%            0.0003166 0.7069 10497
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.719e-02 2.575e-01 3.289e-01 3.949e-01 5.092e-01
# e1_natural_ventilation_rate 5.397e-01 6.653e-01 7.356e-01 8.070e-01 9.590e-01
# %SIGMA@wn2*.pc.mu%          1.387e+05 1.448e+05 1.481e+05 1.513e+05 1.577e+05
# b10_airloophvac             3.269e-01 6.458e-01 8.200e-01 9.472e-01 9.965e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.990e+03 2.075e+03 2.120e+03 2.166e+03 2.259e+03
# %SIGMA@wn2*.pc3%            2.986e+02 3.114e+02 3.184e+02 3.257e+02 3.390e+02
# %SIGMA@wn2*.pc5%            2.452e+01 2.558e+01 2.614e+01 2.672e+01 2.783e+01
# a5_infiltration_rate        7.922e-03 7.157e-02 1.437e-01 2.422e-01 5.655e-01
# %SIGMA@wn2*.pc6%            1.280e+01 1.335e+01 1.364e+01 1.393e+01 1.451e+01
# %SIGMA@wn2*.pc7%            1.268e+01 1.321e+01 1.350e+01 1.380e+01 1.437e+01
#
# *** Simulation 170 / <until converged> (elapsed time: 1.23 mins) ***
#
# Iterations = 1700:62896
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 15300
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# d2_htgsp_office_st          3.231e-01    0.1042 8.427e-04       0.001381
# e1_natural_ventilation_rate 7.379e-01    0.1047 8.463e-04       0.002180
# %SIGMA@wn2*.pc.mu%          1.481e+05 4808.4650 3.887e+01      46.623074
# b10_airloophvac             7.733e-01    0.1985 1.605e-03       0.004583
# %SIGMA@wn2*.pc1%            1.121e+05 3613.9989 2.922e+01      33.861728
# %SIGMA@wn2*.pc2%            2.121e+03   67.9178 5.491e-01       0.653894
# %SIGMA@wn2*.pc3%            3.186e+02   10.4396 8.440e-02       0.099309
# %SIGMA@wn2*.pc5%            2.615e+01    0.8459 6.838e-03       0.008059
# a5_infiltration_rate        1.787e-01    0.1478 1.195e-03       0.001763
# %SIGMA@wn2*.pc6%            1.364e+01    0.4339 3.508e-03       0.004191
# %SIGMA@wn2*.pc7%            1.351e+01    0.4378 3.539e-03       0.004214
#                                     t    eff     s
# d2_htgsp_office_st          0.0042752 0.3721  5693
# e1_natural_ventilation_rate 0.0029540 0.1507  2306
# %SIGMA@wn2*.pc.mu%          0.0003148 0.6952 10637
# b10_airloophvac             0.0059260 0.1226  1876
# %SIGMA@wn2*.pc1%            0.0003022 0.7445 11391
# %SIGMA@wn2*.pc2%            0.0003083 0.7051 10788
# %SIGMA@wn2*.pc3%            0.0003117 0.7223 11051
# %SIGMA@wn2*.pc5%            0.0003081 0.7201 11017
# a5_infiltration_rate        0.0098645 0.4593  7028
# %SIGMA@wn2*.pc6%            0.0003072 0.7005 10718
# %SIGMA@wn2*.pc7%            0.0003120 0.7055 10794
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# d2_htgsp_office_st          8.879e-02 2.581e-01 3.293e-01 3.947e-01 5.091e-01
# e1_natural_ventilation_rate 5.391e-01 6.651e-01 7.354e-01 8.067e-01 9.588e-01
# %SIGMA@wn2*.pc.mu%          1.387e+05 1.448e+05 1.481e+05 1.513e+05 1.576e+05
# b10_airloophvac             3.275e-01 6.455e-01 8.198e-01 9.469e-01 9.965e-01
# %SIGMA@wn2*.pc1%            1.050e+05 1.096e+05 1.120e+05 1.145e+05 1.193e+05
# %SIGMA@wn2*.pc2%            1.991e+03 2.075e+03 2.120e+03 2.167e+03 2.259e+03
# %SIGMA@wn2*.pc3%            2.986e+02 3.114e+02 3.184e+02 3.257e+02 3.390e+02
# %SIGMA@wn2*.pc5%            2.452e+01 2.558e+01 2.614e+01 2.672e+01 2.785e+01
# a5_infiltration_rate        7.982e-03 7.166e-02 1.436e-01 2.418e-01 5.646e-01
# %SIGMA@wn2*.pc6%            1.280e+01 1.335e+01 1.364e+01 1.393e+01 1.451e+01
# %SIGMA@wn2*.pc7%            1.268e+01 1.321e+01 1.350e+01 1.380e+01 1.438e+01
#
# $CALIBRATION_RESULTS
#                     PARAMETER     ESTIMATE        LOWER        UPPER
# 1          d2_htgsp_office_st 14.007873391 1.262463e+01 1.510080e+01
# 2 e1_natural_ventilation_rate  0.657016315 4.904679e-01 8.605416e-01
# 3             b10_airloophvac  0.999041395 8.343224e-01 9.999561e-01
# 4        a5_infiltration_rate  0.000168774 1.610038e-04 2.122345e-04
#
# $CALIBRATED_MODEL_GOF
#               sim        cals
# data1 0.006458169 0.006612391
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 7: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 8: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 9: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 10: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
#
#
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# # Calibro finished successfully.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 7: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 8: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 9: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 10: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
