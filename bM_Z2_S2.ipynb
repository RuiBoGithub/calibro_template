# %% [markdown]
# # Coding

# %%
# Your revised Python pipeline with TT parameter scaling applied correctly

# ---- Unique dir ----
identifier = 'bM_Z2_S2' 
EXP_NAME = identifier

# ---- Column names ----
METERING_COLUMN    = "Main Heating"
START_DATE = "2023-01-01"
END_DATE   = "2023-12-31"
AREA_M2 = 9184

# ---- Source files ----
SRC_METERING = "../ihg_generator/Metering.csv" 
SRC_TT = f"../eplus_diagnosis/idf-Oct/G2/auto-cal/{identifier}/samples.csv" 
SRC_Y = f"../eplus_diagnosis/{identifier}_csv/DistrictHeatingWater_Facility_timeseries.csv"
# ---- R environment ----
CALIBRO_NAME = "simplest"
RSCRIPT_BIN = "Rscript"
PARAM_TO_SCALE = "a5_infiltration_rate"
SCALE_FACTOR = 3600

# ---- Fixed term ----
METERING_TIMESTAMP = "Timestamp"
TT_DROP_COLUMNS = ["CSV File"]

# %%
import pandas as pd
from pathlib import Path
import subprocess
import sys

# ================================================================
# 0. Resolve experiment directories
# ================================================================
base_dir = Path(".").resolve()
exp_dir = base_dir / EXP_NAME

data_dir  = exp_dir / "data"
code_dir  = exp_dir / "code"
output_dir = exp_dir / "output"

for d in [data_dir, code_dir, output_dir]:
    d.mkdir(parents=True, exist_ok=True)

print(f"[INFO] Experiment folder prepared at: {exp_dir}")

# ================================================================
# KEY: Extract TT.csv + rescale chosen parameter
# ================================================================
df_TT = pd.read_csv(SRC_TT)

# Drop unused columns
for col in TT_DROP_COLUMNS:
    if col in df_TT.columns:
        df_TT = df_TT.drop(columns=[col])

# ---- RESCALE ONE PARAMETER ----
if PARAM_TO_SCALE in df_TT.columns:
    df_TT[PARAM_TO_SCALE] = df_TT[PARAM_TO_SCALE] * SCALE_FACTOR
    print(f"[INFO] Scaled parameter '{PARAM_TO_SCALE}' by ×{SCALE_FACTOR}")
else:
    print(f"[WARNING] Parameter '{PARAM_TO_SCALE}' not found in TT columns. Available columns: {list(df_TT.columns)}")

# Save TT
df_TT.to_csv(data_dir / "TT.csv", index=False)
print("[INFO] TT.csv saved:", df_TT.shape)
# Out:
# [INFO] Experiment folder prepared at: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/bM_Z2_S2
# [INFO] Scaled parameter 'a5_infiltration_rate' by ×3600
# [INFO] TT.csv saved: (100, 10)

# %%
import pandas as pd
from pathlib import Path

# ================================================================
# Helpers
# ================================================================

def _aggregate_monthly(df, timestamp_col, value_cols):
    df[timestamp_col] = pd.to_datetime(df[timestamp_col])
    monthly = (
        df.set_index(timestamp_col)[value_cols]
        .resample("M")
        .sum()
        .reset_index(drop=True)
    )
    return monthly

# ================================================================
# 1. Extract obs.csv (hourly or monthly)
# ================================================================

def extract_obs(
    SRC_METERING,
    START_DATE,
    END_DATE,
    METERING_TIMESTAMP,
    METERING_COLUMN,
    AREA_M2,
    data_dir: Path,
    mode="hourly",
):
    df_meter = pd.read_csv(SRC_METERING)
    df_meter[METERING_TIMESTAMP] = pd.to_datetime(df_meter[METERING_TIMESTAMP], dayfirst=True)

    df_obs = df_meter.loc[
        (df_meter[METERING_TIMESTAMP] >= START_DATE)
        & (df_meter[METERING_TIMESTAMP] < END_DATE),
        [METERING_TIMESTAMP, METERING_COLUMN],
    ].copy()

    df_obs[METERING_COLUMN] = df_obs[METERING_COLUMN] / AREA_M2

    if mode == "monthly":
        df_obs = _aggregate_monthly(df_obs, METERING_TIMESTAMP, [METERING_COLUMN])

    df_out = df_obs[[METERING_COLUMN]]
    df_out.to_csv(data_dir / "obs.csv", index=False)
    print("[INFO] obs.csv saved:", df_out.shape)
    return df_out

# ================================================================
# 2. Extract Y.csv (hourly or monthly)
# ================================================================

def extract_Y(
    SRC_Y,
    START_DATE,
    END_DATE,
    data_dir: Path,
    mode="hourly",
):
    df_Y = pd.read_csv(SRC_Y)

    ts_cols = [c for c in df_Y.columns if "time" in c.lower() or "stamp" in c.lower()]
    if not ts_cols:
        raise ValueError("No timestamp column found in Y file")
    ts_col = ts_cols[0]

    df_Y[ts_col] = pd.to_datetime(df_Y[ts_col])

    df_Y_filtered = df_Y.loc[
        (df_Y[ts_col] >= START_DATE)
        & (df_Y[ts_col] < END_DATE)
    ].copy()

    if mode == "monthly":
        value_cols = [c for c in df_Y.columns if c != ts_col]
        df_Y_filtered = _aggregate_monthly(df_Y_filtered, ts_col, value_cols)

    df_Y_final = df_Y_filtered.drop(columns=[ts_col], errors="ignore")

    # NEW: sort Y columns alphabetically
    df_Y_final = df_Y_final.reindex(sorted(df_Y_final.columns), axis=1)

    df_Y_final.to_csv(data_dir / "Y.csv", index=False)
    print("[INFO] Y.csv saved:", df_Y_final.shape)
    return df_Y_final

# ================================================================
# Validation wrapper
# ================================================================

def run_and_validate(SRC_METERING, SRC_Y, START_DATE, END_DATE,
                     METERING_TIMESTAMP, METERING_COLUMN, AREA_M2,
                     data_dir: Path, mode="hourly"):

    df_obs = extract_obs(
        SRC_METERING,
        START_DATE,
        END_DATE,
        METERING_TIMESTAMP,
        METERING_COLUMN,
        AREA_M2,
        data_dir,
        mode=mode,
    )

    df_Y_final = extract_Y(
        SRC_Y,
        START_DATE,
        END_DATE,
        data_dir,
        mode=mode,
    )

    if df_obs.shape[0] != df_Y_final.shape[0]:
        raise ValueError("❌ obs and Y row count mismatch!")

    print("✓ Shape validation passed.")
run_and_validate(SRC_METERING, SRC_Y, START_DATE, END_DATE,
                     METERING_TIMESTAMP, METERING_COLUMN, AREA_M2,
                     data_dir, mode="monthly")
# Out:
# [INFO] obs.csv saved: (12, 1)
# [INFO] Y.csv saved: (12, 100)
# ✓ Shape validation passed.
# /var/folders/7p/_yzdn45s5c7_bd88lqmn1cw80000gn/T/ipykernel_71582/2669456937.py:12: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample("M")
# /var/folders/7p/_yzdn45s5c7_bd88lqmn1cw80000gn/T/ipykernel_71582/2669456937.py:12: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample("M")

# %%
# ================================================================
# 5. Generate R script
# ================================================================
r_script_path = code_dir / "run_calibro.R"

r_code = f"""
setwd("{output_dir}")

library(calibro)

CE <- calEnv$new(name = '{CALIBRO_NAME}')

CE$add.ds(
    name = 'data1',
    Y.star = '{data_dir}/obs.csv',
    TT     = '{data_dir}/TT.csv',
    Y      = '{data_dir}/Y.csv'
)

CE$rd = 'pca'
CE$sa = 'sobolSmthSpl'
CE$ret = list(mthd = 'ng.screening')
CE$mdls = 'gpr.ng.sePar01_whitePar01'
CE$train = list(type = 'training', alg = 'amoeba')
CE$cals = 'cal.gpr.ng'
CE$cal.mcmc = list(alg = 'amg')

CE$cal.res()

# IMPORTANT: no 'path' argument allowed
CE$genReport(
    type = 'pdf',
    out  = c('dss','cal')
)
"""

with open(r_script_path, "w") as f:
    f.write(r_code)

print("[INFO] R script generated:", r_script_path)


# ================================================================
# 6. Run Rscript
# ================================================================
print("\n[INFO] Running Calibro Rscript...")
cmd = [RSCRIPT_BIN, str(r_script_path)]
result = subprocess.run(cmd)

if result.returncode == 0:
    print("✓ Calibro finished successfully.")
else:
    print("❌ Calibro failed.")


print(f"\n🎉 Experiment complete. Results saved to: {output_dir}")
# Out:
# [INFO] R script generated: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/bM_Z2_S2/code/run_calibro.R
#
# [INFO] Running Calibro Rscript...
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-17 15:53:33.812313
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00281 mins) ***
#
#  best y: 738.924955708429
#  best z:
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.2257
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.6788
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 29720000
#
# *** Simulation 2 / 5 (elapsed time: 0.0038 mins) ***
#
#  best y: 738.924955708429
#  best z:
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.2257
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.6788
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 29720000
#
# *** Simulation 3 / 5 (elapsed time: 0.00496 mins) ***
#
#  best y: 738.924955708429
#  best z:
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc.mu = 0.2257
# 	 %RHO@b10_airloophvac%@sePar01.pc.mu = 0.6788
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 29720000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-17 15:53:34.161141
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00204 mins) ***
#
#  best y: 821.05080998153
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc1 = 0.3365
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.03886
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.01246
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 14660000
#
# *** Simulation 2 / 5 (elapsed time: 0.00392 mins) ***
#
#  best y: 821.05080998153
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc1 = 0.3365
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.03886
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.01246
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 14660000
#
# *** Simulation 3 / 5 (elapsed time: 0.00633 mins) ***
#
#  best y: 821.696066431151
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc1 = 0.4745
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 5.048e-05
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.4314
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 15110000
#
# *** Simulation 4 / 5 (elapsed time: 0.00793 mins) ***
#
#  best y: 821.696066431151
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc1 = 0.4745
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 5.048e-05
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.4314
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 15110000
#
# *** Simulation 5 / 5 (elapsed time: 0.0105 mins) ***
#
#  best y: 825.213353231316
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc1 = 0.4618
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.1783
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.46
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 11880000
#
# *** Simulation 6 / 5 (elapsed time: 0.0129 mins) ***
#
#  best y: 825.213353231316
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc1 = 0.4618
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc1 = 0.1783
# 	 %RHO@b10_airloophvac%@sePar01.pc1 = 0.46
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 11880000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-17 15:53:34.985944
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00128 mins) ***
#
#  best y: 412.500437446305
#  best z:
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.01212
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9984
# 	 %SIGMA1@wn2.pc2 = 25210
#
# *** Simulation 2 / 5 (elapsed time: 0.00216 mins) ***
#
#  best y: 412.500437446305
#  best z:
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.01212
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9984
# 	 %SIGMA1@wn2.pc2 = 25210
#
# *** Simulation 3 / 5 (elapsed time: 0.00306 mins) ***
#
#  best y: 412.500437446305
#  best z:
# 	 %RHO@e1_natural_ventilation_rate%@sePar01.pc2 = 0.01212
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9984
# 	 %SIGMA1@wn2.pc2 = 25210
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-17 15:53:35.218663
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00142 mins) ***
#
#  best y: 374.452667499277
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc3 = 0.0004041
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1433
# 	 %ALPHA1@sePar01.pc3 = 0.9992
# 	 %SIGMA1@wn1.pc3 = 0.9981
# 	 %SIGMA1@wn2.pc3 = 1720
#
# *** Simulation 2 / 5 (elapsed time: 0.00258 mins) ***
#
#  best y: 374.452667499277
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc3 = 0.0004041
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1433
# 	 %ALPHA1@sePar01.pc3 = 0.9992
# 	 %SIGMA1@wn1.pc3 = 0.9981
# 	 %SIGMA1@wn2.pc3 = 1720
#
# *** Simulation 3 / 5 (elapsed time: 0.00439 mins) ***
#
#  best y: 376.755040154179
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc3 = 0.001557
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.3301
# 	 %ALPHA1@sePar01.pc3 = 0.9992
# 	 %SIGMA1@wn1.pc3 = 0.9981
# 	 %SIGMA1@wn2.pc3 = 1930
#
# *** Simulation 4 / 5 (elapsed time: 0.00628 mins) ***
#
#  best y: 377.348771040715
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc3 = 0.004573
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1887
# 	 %ALPHA1@sePar01.pc3 = 0.9992
# 	 %SIGMA1@wn1.pc3 = 0.9981
# 	 %SIGMA1@wn2.pc3 = 1804
#
# *** Simulation 5 / 5 (elapsed time: 0.0087 mins) ***
#
#  best y: 377.348771040715
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc3 = 0.004573
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1887
# 	 %ALPHA1@sePar01.pc3 = 0.9992
# 	 %SIGMA1@wn1.pc3 = 0.9981
# 	 %SIGMA1@wn2.pc3 = 1804
#
# *** Simulation 6 / 5 (elapsed time: 0.0101 mins) ***
#
#  best y: 377.348771040715
#  best z:
# 	 %RHO@b12_sat%@sePar01.pc3 = 0.004573
# 	 %RHO@d2_htgsp_office_st%@sePar01.pc3 = 0.1887
# 	 %ALPHA1@sePar01.pc3 = 0.9992
# 	 %SIGMA1@wn1.pc3 = 0.9981
# 	 %SIGMA1@wn2.pc3 = 1804
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2025-11-17 15:53:35.876251
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000957 mins) ***
#
#  best y: 388.740366699386
#  best z:
# 	 %RHO@d1_htgsp_office%@sePar01.pc4 = 0.009066
# 	 %ALPHA1@sePar01.pc4 = 0.9994
# 	 %SIGMA1@wn1.pc4 = 0.9988
# 	 %SIGMA1@wn2.pc4 = 850.4
#
# *** Simulation 2 / 5 (elapsed time: 0.00281 mins) ***
#
#  best y: 389.028094752654
#  best z:
# 	 %RHO@d1_htgsp_office%@sePar01.pc4 = 0.03296
# 	 %ALPHA1@sePar01.pc4 = 0.9995
# 	 %SIGMA1@wn1.pc4 = 0.9989
# 	 %SIGMA1@wn2.pc4 = 862.7
#
# *** Simulation 3 / 5 (elapsed time: 0.0042 mins) ***
#
#  best y: 389.078709198354
#  best z:
# 	 %RHO@d1_htgsp_office%@sePar01.pc4 = 0.02687
# 	 %ALPHA1@sePar01.pc4 = 0.9994
# 	 %SIGMA1@wn1.pc4 = 0.9989
# 	 %SIGMA1@wn2.pc4 = 856.4
#
# *** Simulation 4 / 5 (elapsed time: 0.00525 mins) ***
#
#  best y: 389.078709198354
#  best z:
# 	 %RHO@d1_htgsp_office%@sePar01.pc4 = 0.02687
# 	 %ALPHA1@sePar01.pc4 = 0.9994
# 	 %SIGMA1@wn1.pc4 = 0.9989
# 	 %SIGMA1@wn2.pc4 = 856.4
#
# *** Simulation 5 / 5 (elapsed time: 0.00686 mins) ***
#
#  best y: 389.089464064473
#  best z:
# 	 %RHO@d1_htgsp_office%@sePar01.p
-03
#                                    t    eff    s
# e1_natural_ventilation_rate 0.001937 0.5829 4459
# b10_airloophvac             0.010063 0.5598 4282
# %SIGMA@wn2*.pc.mu%          0.003793 0.6852 5242
# b12_sat                     0.006382 0.6232 4767
# %SIGMA@wn2*.pc1%            0.003733 0.6564 5021
# %SIGMA@wn2*.pc2%            0.003648 0.6903 5281
# d2_htgsp_office_st          0.007898 0.6973 5334
# %SIGMA@wn2*.pc3%            0.003522 0.7082 5418
# d1_htgsp_office             0.007677 0.6287 4809
# %SIGMA@wn2*.pc4%            0.003368 0.7911 6052
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# e1_natural_ventilation_rate 5.999e-01 7.688e-01 8.537e-01 9.279e-01 9.910e-01
# b10_airloophvac             1.699e-02 1.484e-01 2.883e-01 4.506e-01 7.910e-01
# %SIGMA@wn2*.pc.mu%          2.153e+04 3.188e+04 3.902e+04 4.681e+04 6.354e+04
# b12_sat                     6.531e-02 3.945e-01 6.116e-01 7.979e-01 9.765e-01
# %SIGMA@wn2*.pc1%            1.202e+04 1.780e+04 2.140e+04 2.555e+04 3.432e+04
# %SIGMA@wn2*.pc2%            2.110e+01 3.077e+01 3.716e+01 4.433e+01 5.980e+01
# d2_htgsp_office_st          2.428e-02 2.508e-01 4.915e-01 7.439e-01 9.742e-01
# %SIGMA@wn2*.pc3%            1.543e+00 2.250e+00 2.701e+00 3.200e+00 4.321e+00
# d1_htgsp_office             3.345e-02 2.933e-01 5.492e-01 7.866e-01 9.786e-01
# %SIGMA@wn2*.pc4%            6.272e-01 9.290e-01 1.112e+00 1.325e+00 1.803e+00
#
# *** Simulation 90 / <until converged> (elapsed time: 0.337 mins) ***
#
# Iterations = 900:33296
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 8100
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                                  Mean        SD  Naive SE Time-series SE
# e1_natural_ventilation_rate 8.392e-01 1.084e-01 1.204e-03      1.605e-03
# b10_airloophvac             3.158e-01 2.085e-01 2.317e-03      3.086e-03
# %SIGMA@wn2*.pc.mu%          3.985e+04 1.091e+04 1.213e+02      1.462e+02
# b12_sat                     5.840e-01 2.583e-01 2.870e-03      3.634e-03
# %SIGMA@wn2*.pc1%            2.185e+04 5.747e+03 6.386e+01      7.878e+01
# %SIGMA@wn2*.pc2%            3.803e+01 1.009e+01 1.121e-01      1.352e-01
# d2_htgsp_office_st          4.980e-01 2.867e-01 3.185e-03      3.815e-03
# %SIGMA@wn2*.pc3%            2.756e+00 7.163e-01 7.958e-03      9.440e-03
# d1_htgsp_office             5.370e-01 2.864e-01 3.182e-03      4.027e-03
# %SIGMA@wn2*.pc4%            1.140e+00 2.971e-01 3.301e-03      3.754e-03
#                                    t    eff    s
# e1_natural_ventilation_rate 0.001913 0.5629 4560
# b10_airloophvac             0.009773 0.5637 4566
# %SIGMA@wn2*.pc.mu%          0.003668 0.6884 5576
# b12_sat                     0.006222 0.6237 5052
# %SIGMA@wn2*.pc1%            0.003605 0.6570 5322
# %SIGMA@wn2*.pc2%            0.003556 0.6869 5564
# d2_htgsp_office_st          0.007661 0.6971 5647
# %SIGMA@wn2*.pc3%            0.003426 0.7107 5757
# d1_htgsp_office             0.007499 0.6243 5057
# %SIGMA@wn2*.pc4%            0.003294 0.7731 6262
#
# 2. Quantiles for each variable:
#
#                                  2.5%       25%       50%       75%     97.5%
# e1_natural_ventilation_rate 6.002e-01 7.692e-01 8.538e-01 9.284e-01 9.909e-01
# b10_airloophvac             1.599e-02 1.470e-01 2.873e-01 4.492e-01 7.907e-01
# %SIGMA@wn2*.pc.mu%          2.148e+04 3.188e+04 3.905e+04 4.681e+04 6.351e+04
# b12_sat                     6.067e-02 3.926e-01 6.113e-01 7.984e-01 9.771e-01
# %SIGMA@wn2*.pc1%            1.205e+04 1.781e+04 2.136e+04 2.551e+04 3.421e+04
# %SIGMA@wn2*.pc2%            2.111e+01 3.074e+01 3.718e+01 4.437e+01 5.969e+01
# d2_htgsp_office_st          2.426e-02 2.520e-01 4.931e-01 7.458e-01 9.746e-01
# %SIGMA@wn2*.pc3%            1.540e+00 2.240e+00 2.696e+00 3.198e+00 4.319e+00
# d1_htgsp_office             3.314e-02 2.935e-01 5.504e-01 7.879e-01 9.798e-01
# %SIGMA@wn2*.pc4%            6.283e-01 9.310e-01 1.115e+00 1.325e+00 1.802e+00
#
# $CALIBRATION_RESULTS
#                     PARAMETER   ESTIMATE      LOWER     UPPER
# 1 e1_natural_ventilation_rate  1.2956426  0.8599791  1.345390
# 2             b10_airloophvac  0.7695263  0.6441450  1.025799
# 3                     b12_sat 22.9031472 17.0280876 26.014509
# 4          d2_htgsp_office_st 15.9689877 15.0473111 17.851338
# 5             d1_htgsp_office 23.6921312 21.1871511 23.971924
#
# $CALIBRATED_MODEL_GOF
#             sim     cals
# data1 0.9302363 1.010362
# There were 12 warnings (use warnings() to see them)
#
#
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# ✓ Calibro finished successfully.
#
# 🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/Working/1-phd_mainworks/Y3/calibro/bM_Z2_S2/output
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# There were 12 warnings (use warnings() to see them)
